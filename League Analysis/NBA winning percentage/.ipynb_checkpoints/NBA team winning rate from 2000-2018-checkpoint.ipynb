# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame

# %%
file = 'nba.csv'

# %%
df = pd.read_csv(file, encoding="utf-8")
df.head()
# Out:
#               Teams 2000-2001  2001-2002  2002-2003  2003-2004  2004-2005  \
# 0    Atlantic Hawks     0.305      0.402      0.427      0.341      0.159
# 1    Boston Celtics     0.439      0.598      0.537      0.439      0.549
# 2    Denver Nuggets     0.488      0.329      0.207      0.524      0.598
# 3  Dallas Mavericks     0.646      0.695      0.732      0.634      0.707
# 4     Chicago Bulls     0.183      0.256      0.366      0.280      0.573
#
#    2005-2006  2006-2007  2007-2008  2008-2009  ...   2010-2011  2011-2012  \
# 0      0.317      0.366      0.451      0.573  ...       0.537      0.606
# 1      0.402      0.293      0.805      0.756  ...       0.683      0.591
# 2      0.537      0.549      0.610      0.659  ...       0.610      0.576
# 3      0.732      0.817      0.622      0.610  ...       0.695      0.545
# 4      0.500      0.598      0.402      0.500  ...       0.756      0.758
#
#    2012-2013  2013-2014  2014-2015  2015-2016  2016-2017  2017-2018  \
# ...

# %%
fahrenheit, = plt.plot(df["Teams"], df["Avg Winning rate"],color="blue", linewidth=1)

# %%
df.nlargest(5,"Avg Winning rate")
# Out:
#                 Teams 2000-2001  2001-2002  2002-2003  2003-2004  2004-2005  \
# 26  San Antonio Spurs     0.707      0.707      0.732      0.695      0.720
# 3    Dallas Mavericks     0.646      0.695      0.732      0.634      0.707
# 10    Houston Rockets     0.549      0.341      0.524      0.549      0.622
# 15         Miami Heat      0.61      0.439      0.305      0.512      0.720
# 1      Boston Celtics     0.439      0.598      0.537      0.439      0.549
#
#     2005-2006  2006-2007  2007-2008  2008-2009  ...   2010-2011  2011-2012  \
# 26      0.768      0.707      0.683      0.659  ...       0.744      0.758
# 3       0.732      0.817      0.622      0.610  ...       0.695      0.545
# 10      0.415      0.634      0.671      0.646  ...       0.524      0.515
# 15      0.634      0.537      0.183      0.524  ...       0.707      0.697
# 1       0.402      0.293      0.805      0.756  ...       0.683      0.591
#
# ...

# %%
df.nsmallest(5,"Avg Winning rate")
# Out:
#                      Teams 2000-2001  2001-2002  2002-2003  2003-2004  \
# 19         New York Knicks     0.585      0.366      0.451      0.476
# 17  Minnesota Timberwolves     0.573      0.610      0.622      0.707
# 6        Charlotte Hornets      0.52      0.598      0.561      0.537
# 29      Washington Wizards     0.232      0.451      0.451      0.305
# 7            Brooklyn Nets     0.317      0.634      0.598      0.573
#
#     2004-2005  2005-2006  2006-2007  2007-2008  2008-2009  ...   2010-2011  \
# 19      0.402      0.280      0.402      0.280      0.390  ...       0.512
# 17      0.537      0.402      0.390      0.268      0.293  ...       0.207
# 6       0.220      0.317      0.402      0.390      0.427  ...       0.415
# 29      0.549      0.512      0.500      0.524      0.232  ...       0.280
# 7       0.512      0.598      0.500      0.415      0.415  ...       0.293
#
#     2011-2012  2012-2013  2013-2014  2014-2015  2015-2016  2016-2017  \
# ...
