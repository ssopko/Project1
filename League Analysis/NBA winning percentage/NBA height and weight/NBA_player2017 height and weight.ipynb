# %%
import csv
import matplotlib.pyplot as plt
import openweathermapy as ow
import pandas as pd
import requests
import json
import numpy as np
from pandas import DataFrame

# %%
url = "http://data.nba.net/10s/prod/v1/2017/players.json"
response  = requests.get(url)
data = response.json()

# %%
data_playerinfo = data['league']['standard']
data_playerinfo
# Out:
# [{'firstName': 'Alex',
#   'lastName': 'Abrines',
#   'personId': '203518',
#   'teamId': '1610612760',
#   'jersey': '8',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '190',
#   'weightKilograms': '86.2',
#   'dateOfBirthUTC': '1993-08-01',
#   'teams': [{'teamId': '1610612760',
#     'seasonStart': '2016',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612760',
#    'pickNum': '32',
#    'roundNum': '2',
#    'seasonYear': '2013'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '2',
#   'collegeName': '',
#   'lastAffiliation': 'Spain/Spain',
#   'country': 'Spain'},
#  {'firstName': 'Quincy',
#   'lastName': 'Acy',
#   'personId': '203112',
#   'teamId': '1610612751',
#   'jersey': '13',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '7',
#   'heightMeters': '2.01',
#   'weightPounds': '240',
#   'weightKilograms': '108.9',
#   'dateOfBirthUTC': '1990-10-06',
#   'teams': [{'teamId': '1610612761',
#     'seasonStart': '2012',
#     'seasonEnd': '2013'},
#    {'teamId': '1610612758', 'seasonStart': '2013', 'seasonEnd': '2013'},
#    {'teamId': '1610612752', 'seasonStart': '2014', 'seasonEnd': '2014'},
#    {'teamId': '1610612758', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612742', 'seasonStart': '2016', 'seasonEnd': '2016'},
#    {'teamId': '1610612751', 'seasonStart': '2016', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612761',
#    'pickNum': '37',
#    'roundNum': '2',
#    'seasonYear': '2012'},
#   'nbaDebutYear': '2012',
#   'yearsPro': '6',
#   'collegeName': 'Baylor',
#   'lastAffiliation': 'Baylor/USA',
#   'country': 'USA'},
#  {'firstName': 'Steven',
#   'lastName': 'Adams',
#   'personId': '203500',
#   'teamId': '1610612760',
#   'jersey': '12',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '7',
#   'heightInches': '0',
#   'heightMeters': '2.13',
#   'weightPounds': '255',
#   'weightKilograms': '115.7',
#   'dateOfBirthUTC': '1993-07-20',
#   'teams': [{'teamId': '1610612760',
#     'seasonStart': '2013',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612760',
#    'pickNum': '12',
#    'roundNum': '1',
#    'seasonYear': '2013'},
#   'nbaDebutYear': '2013',
#   'yearsPro': '5',
#   'collegeName': 'Pittsburgh',
#   'lastAffiliation': 'Pittsburgh/New Zealand',
#   'country': 'New Zealand'},
#  {'firstName': 'Bam',
#   'lastName': 'Adebayo',
#   'personId': '1628389',
#   'teamId': '1610612748',
#   'jersey': '13',
#   'isActive': True,
#   'pos': 'C-F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '255',
#   'weightKilograms': '115.7',
#   'dateOfBirthUTC': '1997-07-18',
#   'teams': [{'teamId': '1610612748',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612748',
#    'pickNum': '14',
#    'roundNum': '1',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Kentucky',
#   'lastAffiliation': 'Kentucky/USA',
#   'country': 'USA'},
#  {'firstName': 'Kyle',
#   'lastName': 'Adnam',
#   'personId': '27025',
#   'teamId': '15016',
#   'jersey': '8',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Arron',
#   'lastName': 'Afflalo',
#   'personId': '201167',
#   'teamId': '1610612753',
#   'jersey': '4',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '210',
#   'weightKilograms': '95.3',
#   'dateOfBirthUTC': '1985-10-15',
#   'teams': [{'teamId': '1610612765',
#     'seasonStart': '2007',
#     'seasonEnd': '2008'},
#    {'teamId': '1610612743', 'seasonStart': '2009', 'seasonEnd': '2011'},
#    {'teamId': '1610612753', 'seasonStart': '2012', 'seasonEnd': '2013'},
#    {'teamId': '1610612757', 'seasonStart': '2014', 'seasonEnd': '2014'},
#    {'teamId': '1610612743', 'seasonStart': '2014', 'seasonEnd': '2014'},
#    {'teamId': '1610612752', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612758', 'seasonStart': '2016', 'seasonEnd': '2016'},
#    {'teamId': '1610612753', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612765',
#    'pickNum': '27',
#    'roundNum': '1',
#    'seasonYear': '2007'},
#   'nbaDebutYear': '2007',
#   'yearsPro': '11',
#   'collegeName': 'UCLA',
#   'lastAffiliation': 'UCLA/USA',
#   'country': 'USA'},
#  {'firstName': 'Alexis',
#   'lastName': 'Ajinca',
#   'personId': '201582',
#   'teamId': '1610612740',
#   'jersey': '42',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '7',
#   'heightInches': '2',
#   'heightMeters': '2.18',
#   'weightPounds': '248',
#   'weightKilograms': '112.5',
#   'dateOfBirthUTC': '1988-05-06',
#   'teams': [{'teamId': '1610612766',
#     'seasonStart': '2008',
#     'seasonEnd': '2009'},
#    {'teamId': '1610612742', 'seasonStart': '2010', 'seasonEnd': '2010'},
#    {'teamId': '1610612761', 'seasonStart': '2010', 'seasonEnd': '2010'},
#    {'teamId': '1610612740', 'seasonStart': '2013', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612766',
#    'pickNum': '20',
#    'roundNum': '1',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2008',
#   'yearsPro': '7',
#   'collegeName': 'Saint Etienne, France',
#   'lastAffiliation': 'St. Etienne/France',
#   'country': 'France'},
#  {'firstName': 'Josh',
#   'lastName': 'Akognon',
#   'personId': '1962937763',
#   'teamId': '12329',
#   'jersey': '',
#   'isActive': True,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Cole',
#   'lastName': 'Aldrich',
#   'personId': '202332',
#   'teamId': '1610612750',
#   'jersey': '45',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '253',
#   'weightKilograms': '114.8',
#   'dateOfBirthUTC': '1988-10-31',
#   'teams': [{'teamId': '1610612760',
#     'seasonStart': '2010',
#     'seasonEnd': '2011'},
#    {'teamId': '1610612758', 'seasonStart': '2012', 'seasonEnd': '2012'},
#    {'teamId': '1610612745', 'seasonStart': '2012', 'seasonEnd': '2012'},
#    {'teamId': '1610612752', 'seasonStart': '2013', 'seasonEnd': '2014'},
#    {'teamId': '1610612746', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612750', 'seasonStart': '2016', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612740',
#    'pickNum': '11',
#    'roundNum': '1',
#    'seasonYear': '2010'},
#   'nbaDebutYear': '2010',
#   'yearsPro': '8',
#   'collegeName': 'Kansas',
#   'lastAffiliation': 'Kansas/USA',
#   'country': 'USA'},
#  {'firstName': 'LaMarcus',
#   'lastName': 'Aldridge',
#   'personId': '200746',
#   'teamId': '1610612759',
#   'jersey': '12',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '260',
#   'weightKilograms': '117.9',
#   'dateOfBirthUTC': '1985-07-19',
#   'teams': [{'teamId': '1610612757',
#     'seasonStart': '2006',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612759', 'seasonStart': '2015', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612741',
#    'pickNum': '2',
#    'roundNum': '1',
#    'seasonYear': '2006'},
#   'nbaDebutYear': '2006',
#   'yearsPro': '12',
#   'collegeName': 'Texas',
#   'lastAffiliation': 'Texas/USA',
#   'country': 'USA'},
#  {'firstName': 'Jarrett',
#   'lastName': 'Allen',
#   'personId': '1628386',
#   'teamId': '1610612751',
#   'jersey': '31',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '234',
#   'weightKilograms': '106.1',
#   'dateOfBirthUTC': '1998-04-21',
#   'teams': [{'teamId': '1610612751',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612751',
#    'pickNum': '22',
#    'roundNum': '1',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Texas',
#   'lastAffiliation': 'Texas/USA',
#   'country': 'USA'},
#  {'firstName': 'Kadeem',
#   'lastName': 'Allen',
#   'personId': '1628443',
#   'teamId': '1610612738',
#   'jersey': '45',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '3',
#   'heightMeters': '1.9',
#   'weightPounds': '200',
#   'weightKilograms': '90.7',
#   'dateOfBirthUTC': '1993-01-15',
#   'teams': [{'teamId': '1610612738',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612738',
#    'pickNum': '53',
#    'roundNum': '2',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Arizona',
#   'lastAffiliation': 'ArizonaUSA/USA',
#   'country': 'USA'},
#  {'firstName': 'Al-Farouq',
#   'lastName': 'Aminu',
#   'personId': '202329',
#   'teamId': '1610612757',
#   'jersey': '8',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '220',
#   'weightKilograms': '99.8',
#   'dateOfBirthUTC': '1990-09-21',
#   'teams': [{'teamId': '1610612746',
#     'seasonStart': '2010',
#     'seasonEnd': '2010'},
#    {'teamId': '1610612740', 'seasonStart': '2011', 'seasonEnd': '2013'},
#    {'teamId': '1610612742', 'seasonStart': '2014', 'seasonEnd': '2014'},
#    {'teamId': '1610612757', 'seasonStart': '2015', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612746',
#    'pickNum': '8',
#    'roundNum': '1',
#    'seasonYear': '2010'},
#   'nbaDebutYear': '2010',
#   'yearsPro': '8',
#   'collegeName': 'Wake Forest',
#   'lastAffiliation': 'Wake Forest/USA',
#   'country': 'USA'},
#  {'firstName': 'David',
#   'lastName': 'Andersen',
#   'personId': '2431',
#   'teamId': '15016',
#   'jersey': '13',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Justin',
#   'lastName': 'Anderson',
#   'personId': '1626147',
#   'teamId': '1610612755',
#   'jersey': '1',
#   'isActive': True,
#   'pos': 'G-F',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '230',
#   'weightKilograms': '104.3',
#   'dateOfBirthUTC': '1993-11-19',
#   'teams': [{'teamId': '1610612742',
#     'seasonStart': '2015',
#     'seasonEnd': '2016'},
#    {'teamId': '1610612755', 'seasonStart': '2016', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612742',
#    'pickNum': '21',
#    'roundNum': '1',
#    'seasonYear': '2015'},
#   'nbaDebutYear': '2015',
#   'yearsPro': '3',
#   'collegeName': 'Virginia',
#   'lastAffiliation': 'Virginia/USA',
#   'country': 'USA'},
#  {'firstName': 'Kyle',
#   'lastName': 'Anderson',
#   'personId': '203937',
#   'teamId': '1610612759',
#   'jersey': '1',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '230',
#   'weightKilograms': '104.3',
#   'dateOfBirthUTC': '1993-09-20',
#   'teams': [{'teamId': '1610612759',
#     'seasonStart': '2014',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612759',
#    'pickNum': '30',
#    'roundNum': '1',
#    'seasonYear': '2014'},
#   'nbaDebutYear': '2014',
#   'yearsPro': '4',
#   'collegeName': 'UCLA',
#   'lastAffiliation': 'UCLA/USA',
#   'country': 'USA'},
#  {'firstName': 'Ryan',
#   'lastName': 'Anderson',
#   'personId': '201583',
#   'teamId': '1610612745',
#   'jersey': '33',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '240',
#   'weightKilograms': '108.9',
#   'dateOfBirthUTC': '1988-05-06',
#   'teams': [{'teamId': '1610612751',
#     'seasonStart': '2008',
#     'seasonEnd': '2008'},
#    {'teamId': '1610612753', 'seasonStart': '2009', 'seasonEnd': '2011'},
#    {'teamId': '1610612740', 'seasonStart': '2012', 'seasonEnd': '2015'},
#    {'teamId': '1610612745', 'seasonStart': '2016', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612751',
#    'pickNum': '21',
#    'roundNum': '1',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2008',
#   'yearsPro': '10',
#   'collegeName': 'California',
#   'lastAffiliation': 'California/USA',
#   'country': 'USA'},
#  {'firstName': 'Zach',
#   'lastName': 'Andrews',
#   'personId': '1962937812',
#   'teamId': '15017',
#   'jersey': '',
#   'isActive': True,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Ike',
#   'lastName': 'Anigbogu',
#   'personId': '1628387',
#   'teamId': '1610612754',
#   'jersey': '13',
#   'isActive': True,
#   'pos': 'C-F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '262',
#   'weightKilograms': '118.8',
#   'dateOfBirthUTC': '1998-10-16',
#   'teams': [{'teamId': '1610612754',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612754',
#    'pickNum': '47',
#    'roundNum': '2',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'California-Los Angeles',
#   'lastAffiliation': 'UCLA/USA',
#   'country': 'USA'},
#  {'firstName': 'Giannis',
#   'lastName': 'Antetokounmpo',
#   'personId': '203507',
#   'teamId': '1610612749',
#   'jersey': '34',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '222',
#   'weightKilograms': '100.7',
#   'dateOfBirthUTC': '1994-12-06',
#   'teams': [{'teamId': '1610612749',
#     'seasonStart': '2013',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612749',
#    'pickNum': '15',
#    'roundNum': '1',
#    'seasonYear': '2013'},
#   'nbaDebutYear': '2013',
#   'yearsPro': '5',
#   'collegeName': 'Greece',
#   'lastAffiliation': 'Greece/Greece',
#   'country': 'Greece'},
#  {'firstName': 'Carmelo',
#   'lastName': 'Anthony',
#   'personId': '2546',
#   'teamId': '1610612760',
#   'jersey': '7',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '240',
#   'weightKilograms': '108.9',
#   'dateOfBirthUTC': '1984-05-29',
#   'teams': [{'teamId': '1610612743',
#     'seasonStart': '2003',
#     'seasonEnd': '2010'},
#    {'teamId': '1610612752', 'seasonStart': '2010', 'seasonEnd': '2016'},
#    {'teamId': '1610612760', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612743',
#    'pickNum': '3',
#    'roundNum': '1',
#    'seasonYear': '2003'},
#   'nbaDebutYear': '2003',
#   'yearsPro': '15',
#   'collegeName': 'Syracuse',
#   'lastAffiliation': 'Syracuse/USA',
#   'country': 'USA'},
#  {'firstName': 'OG',
#   'lastName': 'Anunoby',
#   'personId': '1628384',
#   'teamId': '1610612761',
#   'jersey': '3',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '235',
#   'weightKilograms': '106.6',
#   'dateOfBirthUTC': '1997-07-17',
#   'teams': [{'teamId': '1610612761',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612761',
#    'pickNum': '23',
#    'roundNum': '1',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Indiana',
#   'lastAffiliation': 'Indiana/United Kingdom',
#   'country': 'United Kingdom'},
#  {'firstName': 'Ryan',
#   'lastName': 'Arcidiacono',
#   'personId': '1627853',
#   'teamId': '1610612741',
#   'jersey': '15',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '3',
#   'heightMeters': '1.9',
#   'weightPounds': '195',
#   'weightKilograms': '88.5',
#   'dateOfBirthUTC': '1994-03-26',
#   'teams': [{'teamId': '1610612741',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Villanova',
#   'lastAffiliation': 'Villanova/USA',
#   'country': 'USA'},
#  {'firstName': 'Trevor',
#   'lastName': 'Ariza',
#   'personId': '2772',
#   'teamId': '1610612745',
#   'jersey': '1',
#   'isActive': True,
#   'pos': 'F-G',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '215',
#   'weightKilograms': '97.5',
#   'dateOfBirthUTC': '1985-06-30',
#   'teams': [{'teamId': '1610612752',
#     'seasonStart': '2004',
#     'seasonEnd': '2005'},
#    {'teamId': '1610612753', 'seasonStart': '2005', 'seasonEnd': '2007'},
#    {'teamId': '1610612747', 'seasonStart': '2007', 'seasonEnd': '2008'},
#    {'teamId': '1610612745', 'seasonStart': '2009', 'seasonEnd': '2009'},
#    {'teamId': '1610612740', 'seasonStart': '2010', 'seasonEnd': '2011'},
#    {'teamId': '1610612764', 'seasonStart': '2012', 'seasonEnd': '2013'},
#    {'teamId': '1610612745', 'seasonStart': '2014', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612752',
#    'pickNum': '43',
#    'roundNum': '2',
#    'seasonYear': '2004'},
#   'nbaDebutYear': '2004',
#   'yearsPro': '14',
#   'collegeName': 'UCLA',
#   'lastAffiliation': 'UCLA/USA',
#   'country': 'USA'},
#  {'firstName': 'Darrell',
#   'lastName': 'Arthur',
#   'personId': '201589',
#   'teamId': '1610612743',
#   'jersey': '00',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '235',
#   'weightKilograms': '106.6',
#   'dateOfBirthUTC': '1988-03-25',
#   'teams': [{'teamId': '1610612763',
#     'seasonStart': '2008',
#     'seasonEnd': '2012'},
#    {'teamId': '1610612743', 'seasonStart': '2013', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612740',
#    'pickNum': '27',
#    'roundNum': '1',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2008',
#   'yearsPro': '9',
#   'collegeName': 'Kansas',
#   'lastAffiliation': 'Kansas/USA',
#   'country': 'USA'},
#  {'firstName': 'Jamel',
#   'lastName': 'Artis',
#   'personId': '1628503',
#   'teamId': '1610612753',
#   'jersey': '0',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '7',
#   'heightMeters': '2.01',
#   'weightPounds': '213',
#   'weightKilograms': '96.6',
#   'dateOfBirthUTC': '1993-01-12',
#   'teams': [{'teamId': '1610612753',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Pittsburgh',
#   'lastAffiliation': 'Pittsburgh/USA',
#   'country': 'USA'},
#  {'firstName': 'Netanel',
#   'lastName': 'Artzi',
#   'personId': '1962937170',
#   'teamId': '',
#   'jersey': '10',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Omer',
#   'lastName': 'Asik',
#   'personId': '201600',
#   'teamId': '1610612741',
#   'jersey': '3',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '7',
#   'heightInches': '0',
#   'heightMeters': '2.13',
#   'weightPounds': '255',
#   'weightKilograms': '115.7',
#   'dateOfBirthUTC': '1986-07-04',
#   'teams': [{'teamId': '1610612741',
#     'seasonStart': '2010',
#     'seasonEnd': '2011'},
#    {'teamId': '1610612745', 'seasonStart': '2012', 'seasonEnd': '2013'},
#    {'teamId': '1610612740', 'seasonStart': '2014', 'seasonEnd': '2017'},
#    {'teamId': '1610612741', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612757',
#    'pickNum': '36',
#    'roundNum': '2',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2010',
#   'yearsPro': '8',
#   'collegeName': 'Turkey',
#   'lastAffiliation': 'Fenerbahce S.K./Turkey',
#   'country': 'Turkey'},
#  {'firstName': 'D.J.',
#   'lastName': 'Augustin',
#   'personId': '201571',
#   'teamId': '1610612753',
#   'jersey': '14',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '0',
#   'heightMeters': '1.83',
#   'weightPounds': '183',
#   'weightKilograms': '83.0',
#   'dateOfBirthUTC': '1987-11-10',
#   'teams': [{'teamId': '1610612766',
#     'seasonStart': '2008',
#     'seasonEnd': '2011'},
#    {'teamId': '1610612754', 'seasonStart': '2012', 'seasonEnd': '2012'},
#    {'teamId': '1610612741', 'seasonStart': '2013', 'seasonEnd': '2013'},
#    {'teamId': '1610612761', 'seasonStart': '2013', 'seasonEnd': '2013'},
#    {'teamId': '1610612765', 'seasonStart': '2014', 'seasonEnd': '2014'},
#    {'teamId': '1610612760', 'seasonStart': '2014', 'seasonEnd': '2015'},
#    {'teamId': '1610612743', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612753', 'seasonStart': '2016', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612766',
#    'pickNum': '9',
#    'roundNum': '1',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2008',
#   'yearsPro': '10',
#   'collegeName': 'Texas',
#   'lastAffiliation': 'Texas/USA',
#   'country': 'USA'},
#  {'firstName': 'Luke',
#   'lastName': 'Babbitt',
#   'personId': '202337',
#   'teamId': '1610612748',
#   'jersey': '22',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '225',
#   'weightKilograms': '102.1',
#   'dateOfBirthUTC': '1989-06-20',
#   'teams': [{'teamId': '1610612757',
#     'seasonStart': '2010',
#     'seasonEnd': '2012'},
#    {'teamId': '1610612740', 'seasonStart': '2013', 'seasonEnd': '2015'},
#    {'teamId': '1610612748', 'seasonStart': '2016', 'seasonEnd': '2016'},
#    {'teamId': '1610612737', 'seasonStart': '2017', 'seasonEnd': '2017'},
#    {'teamId': '1610612748', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612750',
#    'pickNum': '16',
#    'roundNum': '1',
#    'seasonYear': '2010'},
#   'nbaDebutYear': '2010',
#   'yearsPro': '8',
#   'collegeName': 'Nevada',
#   'lastAffiliation': 'Nevada-Reno/USA',
#   'country': 'USA'},
#  {'firstName': 'Dwayne',
#   'lastName': 'Bacon',
#   'personId': '1628407',
#   'teamId': '1610612766',
#   'jersey': '7',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '7',
#   'heightMeters': '2.01',
#   'weightPounds': '221',
#   'weightKilograms': '100.2',
#   'dateOfBirthUTC': '1995-08-30',
#   'teams': [{'teamId': '1610612766',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612740',
#    'pickNum': '40',
#    'roundNum': '2',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Florida State',
#   'lastAffiliation': 'Florida State/USA',
#   'country': 'USA'},
#  {'firstName': 'Ron',
#   'lastName': 'Baker',
#   'personId': '1627758',
#   'teamId': '1610612752',
#   'jersey': '31',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '4',
#   'heightMeters': '1.93',
#   'weightPounds': '220',
#   'weightKilograms': '99.8',
#   'dateOfBirthUTC': '1993-03-30',
#   'teams': [{'teamId': '1610612752',
#     'seasonStart': '2016',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2016',
#   'yearsPro': '2',
#   'collegeName': 'Wichita State',
#   'lastAffiliation': 'Wichita State/USA',
#   'country': 'USA'},
#  {'firstName': 'Wade',
#   'lastName': 'Baldwin IV',
#   'personId': '1627735',
#   'teamId': '1610612757',
#   'jersey': '2',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '4',
#   'heightMeters': '1.93',
#   'weightPounds': '202',
#   'weightKilograms': '91.6',
#   'dateOfBirthUTC': '1996-03-29',
#   'teams': [{'teamId': '1610612763',
#     'seasonStart': '2016',
#     'seasonEnd': '2016'},
#    {'teamId': '1610612757', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612763',
#    'pickNum': '17',
#    'roundNum': '1',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '2',
#   'collegeName': 'Vanderbilt',
#   'lastAffiliation': 'Vanderbilt/USA',
#   'country': 'USA'},
#  {'firstName': 'Lonzo',
#   'lastName': 'Ball',
#   'personId': '1628366',
#   'teamId': '1610612747',
#   'jersey': '2',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '190',
#   'weightKilograms': '86.2',
#   'dateOfBirthUTC': '1997-10-27',
#   'teams': [{'teamId': '1610612747',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612747',
#    'pickNum': '2',
#    'roundNum': '1',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'California-Los Angeles',
#   'lastAffiliation': 'UCLA/USA',
#   'country': 'USA'},
#  {'firstName': 'J.J.',
#   'lastName': 'Barea',
#   'personId': '200826',
#   'teamId': '1610612742',
#   'jersey': '5',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '0',
#   'heightMeters': '1.83',
#   'weightPounds': '185',
#   'weightKilograms': '83.9',
#   'dateOfBirthUTC': '1984-06-26',
#   'teams': [{'teamId': '1610612742',
#     'seasonStart': '2006',
#     'seasonEnd': '2010'},
#    {'teamId': '1610612750', 'seasonStart': '2011', 'seasonEnd': '2013'},
#    {'teamId': '1610612742', 'seasonStart': '2014', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2006',
#   'yearsPro': '12',
#   'collegeName': 'Northeastern',
#   'lastAffiliation': 'Northeastern/Puerto Rico',
#   'country': 'Puerto Rico'},
#  {'firstName': 'David',
#   'lastName': 'Barlow',
#   'personId': '6664001',
#   'teamId': '15016',
#   'jersey': '20',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Harrison',
#   'lastName': 'Barnes',
#   'personId': '203084',
#   'teamId': '1610612742',
#   'jersey': '40',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '225',
#   'weightKilograms': '102.1',
#   'dateOfBirthUTC': '1992-05-30',
#   'teams': [{'teamId': '1610612744',
#     'seasonStart': '2012',
#     'seasonEnd': '2015'},
#    {'teamId': '1610612742', 'seasonStart': '2016', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612744',
#    'pickNum': '7',
#    'roundNum': '1',
#    'seasonYear': '2012'},
#   'nbaDebutYear': '2012',
#   'yearsPro': '6',
#   'collegeName': 'North Carolina',
#   'lastAffiliation': 'North Carolina/USA',
#   'country': 'USA'},
#  {'firstName': 'Will',
#   'lastName': 'Barton',
#   'personId': '203115',
#   'teamId': '1610612743',
#   'jersey': '5',
#   'isActive': True,
#   'pos': 'F-G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '190',
#   'weightKilograms': '86.2',
#   'dateOfBirthUTC': '1991-01-06',
#   'teams': [{'teamId': '1610612757',
#     'seasonStart': '2012',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612743', 'seasonStart': '2014', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612757',
#    'pickNum': '40',
#    'roundNum': '2',
#    'seasonYear': '2012'},
#   'nbaDebutYear': '2012',
#   'yearsPro': '6',
#   'collegeName': 'Memphis',
#   'lastAffiliation': 'Memphis/USA',
#   'country': 'USA'},
#  {'firstName': 'Gal',
#   'lastName': 'Baruch',
#   'personId': '27032',
#   'teamId': '',
#   'jersey': '2',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Nicolas',
#   'lastName': 'Batum',
#   'personId': '201587',
#   'teamId': '1610612766',
#   'jersey': '5',
#   'isActive': True,
#   'pos': 'G-F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '200',
#   'weightKilograms': '90.7',
#   'dateOfBirthUTC': '1988-12-14',
#   'teams': [{'teamId': '1610612757',
#     'seasonStart': '2008',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612766', 'seasonStart': '2015', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612745',
#    'pickNum': '25',
#    'roundNum': '1',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2008',
#   'yearsPro': '10',
#   'collegeName': 'Lisieux, France',
#   'lastAffiliation': 'Le Mans/France',
#   'country': 'France'},
#  {'firstName': 'Jerryd',
#   'lastName': 'Bayless',
#   'personId': '201573',
#   'teamId': '1610612755',
#   'jersey': '0',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '3',
#   'heightMeters': '1.9',
#   'weightPounds': '200',
#   'weightKilograms': '90.7',
#   'dateOfBirthUTC': '1988-08-20',
#   'teams': [{'teamId': '1610612757',
#     'seasonStart': '2008',
#     'seasonEnd': '2009'},
#    {'teamId': '1610612740', 'seasonStart': '2010', 'seasonEnd': '2010'},
#    {'teamId': '1610612761', 'seasonStart': '2010', 'seasonEnd': '2011'},
#    {'teamId': '1610612763', 'seasonStart': '2012', 'seasonEnd': '2013'},
#    {'teamId': '1610612738', 'seasonStart': '2013', 'seasonEnd': '2013'},
#    {'teamId': '1610612749', 'seasonStart': '2014', 'seasonEnd': '2015'},
#    {'teamId': '1610612755', 'seasonStart': '2016', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612754',
#    'pickNum': '11',
#    'roundNum': '1',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2008',
#   'yearsPro': '10',
#   'collegeName': 'Arizona',
#   'lastAffiliation': 'Arizona/USA',
#   'country': 'USA'},
#  {'firstName': 'Aron',
#   'lastName': 'Baynes',
#   'personId': '203382',
#   'teamId': '1610612738',
#   'jersey': '46',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '260',
#   'weightKilograms': '117.9',
#   'dateOfBirthUTC': '1986-12-09',
#   'teams': [{'teamId': '1610612759',
#     'seasonStart': '2012',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612765', 'seasonStart': '2015', 'seasonEnd': '2016'},
#    {'teamId': '1610612738', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2012',
#   'yearsPro': '6',
#   'collegeName': 'Washington State',
#   'lastAffiliation': 'Washington State/Australia',
#   'country': 'Australia'},
#  {'firstName': 'Kent',
#   'lastName': 'Bazemore',
#   'personId': '203145',
#   'teamId': '1610612737',
#   'jersey': '24',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '201',
#   'weightKilograms': '91.2',
#   'dateOfBirthUTC': '1989-07-01',
#   'teams': [{'teamId': '1610612744',
#     'seasonStart': '2012',
#     'seasonEnd': '2013'},
#    {'teamId': '1610612747', 'seasonStart': '2013', 'seasonEnd': '2013'},
#    {'teamId': '1610612737', 'seasonStart': '2014', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2012',
#   'yearsPro': '6',
#   'collegeName': 'Old Dominion',
#   'lastAffiliation': 'Old Dominion/USA',
#   'country': 'USA'},
#  {'firstName': 'Bradley',
#   'lastName': 'Beal',
#   'personId': '203078',
#   'teamId': '1610612764',
#   'jersey': '3',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '207',
#   'weightKilograms': '93.9',
#   'dateOfBirthUTC': '1993-06-28',
#   'teams': [{'teamId': '1610612764',
#     'seasonStart': '2012',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612764',
#    'pickNum': '3',
#    'roundNum': '1',
#    'seasonYear': '2012'},
#   'nbaDebutYear': '2012',
#   'yearsPro': '6',
#   'collegeName': 'Florida',
#   'lastAffiliation': 'Florida/USA',
#   'country': 'USA'},
#  {'firstName': 'Malik',
#   'lastName': 'Beasley',
#   'personId': '1627736',
#   'teamId': '1610612743',
#   'jersey': '25',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '196',
#   'weightKilograms': '88.9',
#   'dateOfBirthUTC': '1996-11-26',
#   'teams': [{'teamId': '1610612743',
#     'seasonStart': '2016',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612743',
#    'pickNum': '19',
#    'roundNum': '1',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '2',
#   'collegeName': 'Florida State',
#   'lastAffiliation': 'Florida State/USA',
#   'country': 'USA'},
#  {'firstName': 'Michael',
#   'lastName': 'Beasley',
#   'personId': '201563',
#   'teamId': '1610612752',
#   'jersey': '8',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '235',
#   'weightKilograms': '106.6',
#   'dateOfBirthUTC': '1989-01-09',
#   'teams': [{'teamId': '1610612748',
#     'seasonStart': '2008',
#     'seasonEnd': '2009'},
#    {'teamId': '1610612750', 'seasonStart': '2010', 'seasonEnd': '2011'},
#    {'teamId': '1610612756', 'seasonStart': '2012', 'seasonEnd': '2012'},
#    {'teamId': '1610612748', 'seasonStart': '2013', 'seasonEnd': '2014'},
#    {'teamId': '1610612745', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612749', 'seasonStart': '2016', 'seasonEnd': '2016'},
#    {'teamId': '1610612752', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612748',
#    'pickNum': '2',
#    'roundNum': '1',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2008',
#   'yearsPro': '10',
#   'collegeName': 'Kansas State',
#   'lastAffiliation': 'Kansas State/USA',
#   'country': 'USA'},
#  {'firstName': 'Marco',
#   'lastName': 'Belinelli',
#   'personId': '201158',
#   'teamId': '1610612755',
#   'jersey': '18',
#   'isActive': True,
#   'pos': 'G-F',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '210',
#   'weightKilograms': '95.3',
#   'dateOfBirthUTC': '1986-03-25',
#   'teams': [{'teamId': '1610612744',
#     'seasonStart': '2007',
#     'seasonEnd': '2008'},
#    {'teamId': '1610612761', 'seasonStart': '2009', 'seasonEnd': '2009'},
#    {'teamId': '1610612740', 'seasonStart': '2010', 'seasonEnd': '2011'},
#    {'teamId': '1610612741', 'seasonStart': '2012', 'seasonEnd': '2012'},
#    {'teamId': '1610612759', 'seasonStart': '2013', 'seasonEnd': '2014'},
#    {'teamId': '1610612758', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612766', 'seasonStart': '2016', 'seasonEnd': '2016'},
#    {'teamId': '1610612737', 'seasonStart': '2017', 'seasonEnd': '2017'},
#    {'teamId': '1610612755', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612744',
#    'pickNum': '18',
#    'roundNum': '1',
#    'seasonYear': '2007'},
#   'nbaDebutYear': '2007',
#   'yearsPro': '11',
#   'collegeName': 'Bologna, Italy',
#   'lastAffiliation': 'Fortitudo Bologna/Italy',
#   'country': 'Italy'},
#  {'firstName': 'Jordan',
#   'lastName': 'Bell',
#   'personId': '1628395',
#   'teamId': '1610612744',
#   'jersey': '2',
#   'isActive': True,
#   'pos': 'C-F',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '224',
#   'weightKilograms': '101.6',
#   'dateOfBirthUTC': '1995-01-07',
#   'teams': [{'teamId': '1610612744',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612741',
#    'pickNum': '38',
#    'roundNum': '2',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Oregon',
#   'lastAffiliation': 'Oregon/USA',
#   'country': 'USA'},
#  {'firstName': "DeAndre'",
#   'lastName': 'Bembry',
#   'personId': '1627761',
#   'teamId': '1610612737',
#   'jersey': '95',
#   'isActive': True,
#   'pos': 'F-G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '210',
#   'weightKilograms': '95.3',
#   'dateOfBirthUTC': '1994-07-04',
#   'teams': [{'teamId': '1610612737',
#     'seasonStart': '2016',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612737',
#    'pickNum': '21',
#    'roundNum': '1',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '2',
#   'collegeName': "Saint Joseph's",
#   'lastAffiliation': "St. Joseph's (PA)/USA",
#   'country': 'USA'},
#  {'firstName': 'Dragan',
#   'lastName': 'Bender',
#   'personId': '1627733',
#   'teamId': '1610612756',
#   'jersey': '35',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '7',
#   'heightInches': '1',
#   'heightMeters': '2.16',
#   'weightPounds': '225',
#   'weightKilograms': '102.1',
#   'dateOfBirthUTC': '1997-11-17',
#   'teams': [{'teamId': '1610612756',
#     'seasonStart': '2016',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612756',
#    'pickNum': '4',
#    'roundNum': '1',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '2',
#   'collegeName': '',
#   'lastAffiliation': 'Croatia/Croatia',
#   'country': 'Croatia'},
#  {'firstName': 'Davis',
#   'lastName': 'Bertans',
#   'personId': '202722',
#   'teamId': '1610612759',
#   'jersey': '42',
#   'isActive': True,
#   'pos': 'C-F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '210',
#   'weightKilograms': '95.3',
#   'dateOfBirthUTC': '1992-11-12',
#   'teams': [{'teamId': '1610612759',
#     'seasonStart': '2016',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612754',
#    'pickNum': '42',
#    'roundNum': '2',
#    'seasonYear': '2011'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '2',
#   'collegeName': '',
#   'lastAffiliation': ' Latvia/Latvia',
#   'country': 'Latvia'},
#  {'firstName': 'Patrick',
#   'lastName': 'Beverley',
#   'personId': '201976',
#   'teamId': '1610612746',
#   'jersey': '21',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '1',
#   'heightMeters': '1.85',
#   'weightPounds': '185',
#   'weightKilograms': '83.9',
#   'dateOfBirthUTC': '1988-07-12',
#   'teams': [{'teamId': '1610612745',
#     'seasonStart': '2012',
#     'seasonEnd': '2016'},
#    {'teamId': '1610612746', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612747',
#    'pickNum': '42',
#    'roundNum': '2',
#    'seasonYear': '2009'},
#   'nbaDebutYear': '2012',
#   'yearsPro': '6',
#   'collegeName': 'Arkansas',
#   'lastAffiliation': 'Arkansas/USA',
#   'country': 'USA'},
#  {'firstName': 'Khem',
#   'lastName': 'Birch',
#   'personId': '203920',
#   'teamId': '1610612753',
#   'jersey': '24',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '220',
#   'weightKilograms': '99.8',
#   'dateOfBirthUTC': '1992-09-28',
#   'teams': [{'teamId': '1610612753',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Nevada-Las Vegas',
#   'lastAffiliation': 'Nevada-Las Vegas/Canada',
#   'country': 'Canada'},
#  {'firstName': 'Jabari',
#   'lastName': 'Bird',
#   'personId': '1628444',
#   'teamId': '1610612738',
#   'jersey': '26',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '198',
#   'weightKilograms': '89.8',
#   'dateOfBirthUTC': '1994-07-03',
#   'teams': [{'teamId': '1610612738',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612738',
#    'pickNum': '56',
#    'roundNum': '2',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'California',
#   'lastAffiliation': 'California/USA',
#   'country': 'USA'},
#  {'firstName': 'Bismack',
#   'lastName': 'Biyombo',
#   'personId': '202687',
#   'teamId': '1610612753',
#   'jersey': '11',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '255',
#   'weightKilograms': '115.7',
#   'dateOfBirthUTC': '1992-08-28',
#   'teams': [{'teamId': '1610612766',
#     'seasonStart': '2011',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612761', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612753', 'seasonStart': '2016', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612758',
#    'pickNum': '7',
#    'roundNum': '1',
#    'seasonYear': '2011'},
#   'nbaDebutYear': '2011',
#   'yearsPro': '7',
#   'collegeName': 'Lubumbashi, DR Congo',
#   'lastAffiliation': 'Baloncesto Fuenlabrada/Democratic Republic of Cong',
#   'country': 'Democratic Republic of the Congo'},
#  {'firstName': 'Nemanja',
#   'lastName': 'Bjelica',
#   'personId': '202357',
#   'teamId': '1610612750',
#   'jersey': '8',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '230',
#   'weightKilograms': '104.3',
#   'dateOfBirthUTC': '1988-05-09',
#   'teams': [{'teamId': '1610612750',
#     'seasonStart': '2015',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612764',
#    'pickNum': '35',
#    'roundNum': '2',
#    'seasonYear': '2010'},
#   'nbaDebutYear': '2015',
#   'yearsPro': '3',
#   'collegeName': '',
#   'lastAffiliation': 'Fenerbahce Ulker/Serbia',
#   'country': 'Serbia'},
#  {'firstName': 'Tarik',
#   'lastName': 'Black',
#   'personId': '204028',
#   'teamId': '1610612745',
#   'jersey': '28',
#   'isActive': True,
#   'pos': 'F-C',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '250',
#   'weightKilograms': '113.4',
#   'dateOfBirthUTC': '1991-11-22',
#   'teams': [{'teamId': '1610612745',
#     'seasonStart': '2014',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612747', 'seasonStart': '2014', 'seasonEnd': '2016'},
#    {'teamId': '1610612745', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2014',
#   'yearsPro': '4',
#   'collegeName': 'Kansas',
#   'lastAffiliation': 'KansasUSA/USA',
#   'country': 'USA'},
#  {'firstName': 'Antonio',
#   'lastName': 'Blakeney',
#   'personId': '1628469',
#   'teamId': '1610612741',
#   'jersey': '9',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '4',
#   'heightMeters': '1.93',
#   'weightPounds': '197',
#   'weightKilograms': '89.4',
#   'dateOfBirthUTC': '1996-10-04',
#   'teams': [{'teamId': '1610612741',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Louisiana State',
#   'lastAffiliation': 'Louisiana State/USA',
#   'country': 'USA'},
#  {'firstName': 'Todd',
#   'lastName': 'Blanchfield',
#   'personId': '1962937736',
#   'teamId': '15015',
#   'jersey': '',
#   'isActive': True,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Oz',
#   'lastName': 'Blayzer',
#   'personId': '1962937156',
#   'teamId': '',
#   'jersey': '14',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Eric',
#   'lastName': 'Bledsoe',
#   'personId': '202339',
#   'teamId': '1610612749',
#   'jersey': '6',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '1',
#   'heightMeters': '1.85',
#   'weightPounds': '205',
#   'weightKilograms': '93.0',
#   'dateOfBirthUTC': '1989-12-09',
#   'teams': [{'teamId': '1610612746',
#     'seasonStart': '2010',
#     'seasonEnd': '2012'},
#    {'teamId': '1610612756', 'seasonStart': '2013', 'seasonEnd': '2017'},
#    {'teamId': '1610612749', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612760',
#    'pickNum': '18',
#    'roundNum': '1',
#    'seasonYear': '2010'},
#   'nbaDebutYear': '2010',
#   'yearsPro': '8',
#   'collegeName': 'Kentucky',
#   'lastAffiliation': 'Kentucky/USA',
#   'country': 'USA'},
#  {'firstName': 'Bogdan',
#   'lastName': 'Bogdanovic',
#   'personId': '203992',
#   'teamId': '1610612758',
#   'jersey': '8',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '205',
#   'weightKilograms': '93.0',
#   'dateOfBirthUTC': '1992-08-18',
#   'teams': [{'teamId': '1610612758',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612756',
#    'pickNum': '27',
#    'roundNum': '1',
#    'seasonYear': '2014'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': '',
#   'lastAffiliation': ' Serbia/Serbia',
#   'country': 'Serbia'},
#  {'firstName': 'Bojan',
#   'lastName': 'Bogdanovic',
#   'personId': '202711',
#   'teamId': '1610612754',
#   'jersey': '44',
#   'isActive': True,
#   'pos': 'F-G',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '230',
#   'weightKilograms': '104.3',
#   'dateOfBirthUTC': '1989-04-18',
#   'teams': [{'teamId': '1610612751',
#     'seasonStart': '2014',
#     'seasonEnd': '2016'},
#    {'teamId': '1610612764', 'seasonStart': '2016', 'seasonEnd': '2016'},
#    {'teamId': '1610612754', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612748',
#    'pickNum': '31',
#    'roundNum': '2',
#    'seasonYear': '2011'},
#   'nbaDebutYear': '2014',
#   'yearsPro': '4',
#   'collegeName': '',
#   'lastAffiliation': 'Croatia/Croatia',
#   'country': 'Croatia'},
#  {'firstName': 'Devin',
#   'lastName': 'Booker',
#   'personId': '1626164',
#   'teamId': '1610612756',
#   'jersey': '1',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '210',
#   'weightKilograms': '95.3',
#   'dateOfBirthUTC': '1996-10-30',
#   'teams': [{'teamId': '1610612756',
#     'seasonStart': '2015',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612756',
#    'pickNum': '13',
#    'roundNum': '1',
#    'seasonYear': '2015'},
#   'nbaDebutYear': '2015',
#   'yearsPro': '3',
#   'collegeName': 'Kentucky',
#   'lastAffiliation': 'Kentucky/USA',
#   'country': 'USA'},
#  {'firstName': 'Trevor',
#   'lastName': 'Booker',
#   'personId': '202344',
#   'teamId': '1610612754',
#   'jersey': '20',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '228',
#   'weightKilograms': '103.4',
#   'dateOfBirthUTC': '1987-11-25',
#   'teams': [{'teamId': '1610612764',
#     'seasonStart': '2010',
#     'seasonEnd': '2013'},
#    {'teamId': '1610612762', 'seasonStart': '2014', 'seasonEnd': '2015'},
#    {'teamId': '1610612751', 'seasonStart': '2016', 'seasonEnd': '2017'},
#    {'teamId': '1610612755', 'seasonStart': '2017', 'seasonEnd': '2017'},
#    {'teamId': '1610612754', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612750',
#    'pickNum': '23',
#    'roundNum': '1',
#    'seasonYear': '2010'},
#   'nbaDebutYear': '2010',
#   'yearsPro': '8',
#   'collegeName': 'Clemson',
#   'lastAffiliation': 'Clemson/USA',
#   'country': 'USA'},
#  {'firstName': 'Josh',
#   'lastName': 'Boone',
#   'personId': '51956',
#   'teamId': '15016',
#   'jersey': '3',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Chris',
#   'lastName': 'Boucher',
#   'personId': '1628449',
#   'teamId': '1610612744',
#   'jersey': '25',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '200',
#   'weightKilograms': '90.7',
#   'dateOfBirthUTC': '1993-01-11',
#   'teams': [{'teamId': '1610612744',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': 'Oregon',
#   'lastAffiliation': 'Oregon/Canada',
#   'country': 'Canada'},
#  {'firstName': 'Frederic',
#   'lastName': 'Bourdillon',
#   'personId': '27033',
#   'teamId': '',
#   'jersey': '7',
# ...
#   'jersey': '55',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '190',
#   'weightKilograms': '86.2',
#   'dateOfBirthUTC': '1992-04-26',
#   'teams': [{'teamId': '1610612761',
#     'seasonStart': '2015',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612761',
#    'pickNum': '20',
#    'roundNum': '1',
#    'seasonYear': '2015'},
#   'nbaDebutYear': '2015',
#   'yearsPro': '3',
#   'collegeName': 'Utah',
#   'lastAffiliation': 'Utah/USA',
#   'country': 'USA'},
#  {'firstName': 'Zhang',
#   'lastName': 'Xiaolei',
#   'personId': '27004',
#   'teamId': '15018',
#   'jersey': '6',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Huang',
#   'lastName': 'Xu',
#   'personId': '1962937760',
#   'teamId': '12329',
#   'jersey': '',
#   'isActive': True,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Luo',
#   'lastName': 'Xuedong',
#   'personId': '27001',
#   'teamId': '15018',
#   'jersey': '6',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Zhu',
#   'lastName': 'Xuhang',
#   'personId': '27006',
#   'teamId': '15018',
#   'jersey': '10',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Guerschon',
#   'lastName': 'Yabusele',
#   'personId': '1627824',
#   'teamId': '1610612738',
#   'jersey': '30',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '260',
#   'weightKilograms': '117.9',
#   'dateOfBirthUTC': '1995-12-17',
#   'teams': [{'teamId': '1610612738',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612738',
#    'pickNum': '16',
#    'roundNum': '1',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': '',
#   'lastAffiliation': 'France/France',
#   'country': 'France'},
#  {'firstName': 'Zhai',
#   'lastName': 'Yi',
#   'personId': '1962937765',
#   'teamId': '12329',
#   'jersey': '',
#   'isActive': True,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Heng',
#   'lastName': 'Yifeng',
#   'personId': '27012',
#   'teamId': '15018',
#   'jersey': '21',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Chen',
#   'lastName': 'Yingjun',
#   'personId': '27008',
#   'teamId': '15018',
#   'jersey': '',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Dagan',
#   'lastName': 'Yivzuri',
#   'personId': '42573',
#   'teamId': '',
#   'jersey': '8',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Joe',
#   'lastName': 'Young',
#   'personId': '1626202',
#   'teamId': '1610612754',
#   'jersey': '3',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '2',
#   'heightMeters': '1.88',
#   'weightPounds': '185',
#   'weightKilograms': '83.9',
#   'dateOfBirthUTC': '1992-06-27',
#   'teams': [{'teamId': '1610612754',
#     'seasonStart': '2015',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612754',
#    'pickNum': '43',
#    'roundNum': '2',
#    'seasonYear': '2015'},
#   'nbaDebutYear': '2015',
#   'yearsPro': '3',
#   'collegeName': 'Oregon',
#   'lastAffiliation': 'Oregon/USA',
#   'country': 'USA'},
#  {'firstName': 'Mitchell',
#   'lastName': 'Young',
#   'personId': '27018',
#   'teamId': '15017',
#   'jersey': '3',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Nick',
#   'lastName': 'Young',
#   'personId': '201156',
#   'teamId': '1610612744',
#   'jersey': '6',
#   'isActive': True,
#   'pos': 'G-F',
#   'heightFeet': '6',
#   'heightInches': '7',
#   'heightMeters': '2.01',
#   'weightPounds': '210',
#   'weightKilograms': '95.3',
#   'dateOfBirthUTC': '1985-06-01',
#   'teams': [{'teamId': '1610612764',
#     'seasonStart': '2007',
#     'seasonEnd': '2011'},
#    {'teamId': '1610612746', 'seasonStart': '2011', 'seasonEnd': '2011'},
#    {'teamId': '1610612755', 'seasonStart': '2012', 'seasonEnd': '2012'},
#    {'teamId': '1610612747', 'seasonStart': '2013', 'seasonEnd': '2016'},
#    {'teamId': '1610612744', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612764',
#    'pickNum': '16',
#    'roundNum': '1',
#    'seasonYear': '2007'},
#   'nbaDebutYear': '2007',
#   'yearsPro': '11',
#   'collegeName': 'Southern California',
#   'lastAffiliation': 'USC/USA',
#   'country': 'USA'},
#  {'firstName': 'Thaddeus',
#   'lastName': 'Young',
#   'personId': '201152',
#   'teamId': '1610612754',
#   'jersey': '21',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '230',
#   'weightKilograms': '104.3',
#   'dateOfBirthUTC': '1988-06-21',
#   'teams': [{'teamId': '1610612755',
#     'seasonStart': '2007',
#     'seasonEnd': '2013'},
#    {'teamId': '1610612750', 'seasonStart': '2014', 'seasonEnd': '2014'},
#    {'teamId': '1610612751', 'seasonStart': '2014', 'seasonEnd': '2015'},
#    {'teamId': '1610612754', 'seasonStart': '2016', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612755',
#    'pickNum': '12',
#    'roundNum': '1',
#    'seasonYear': '2007'},
#   'nbaDebutYear': '2007',
#   'yearsPro': '11',
#   'collegeName': 'Georgia Tech',
#   'lastAffiliation': 'Georgia Tech/USA',
#   'country': 'USA'},
#  {'firstName': 'Shi',
#   'lastName': 'Yuchen',
#   'personId': '1962937772',
#   'teamId': '12329',
#   'jersey': '',
#   'isActive': True,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Wang',
#   'lastName': 'Yue',
#   'personId': '27003',
#   'teamId': '15018',
#   'jersey': '32',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Gu',
#   'lastName': 'Yuezhuo',
#   'personId': '27010',
#   'teamId': '15018',
#   'jersey': '7',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Cody',
#   'lastName': 'Zeller',
#   'personId': '203469',
#   'teamId': '1610612766',
#   'jersey': '40',
#   'isActive': True,
#   'pos': 'C-F',
#   'heightFeet': '7',
#   'heightInches': '0',
#   'heightMeters': '2.13',
#   'weightPounds': '240',
#   'weightKilograms': '108.9',
#   'dateOfBirthUTC': '1992-10-05',
#   'teams': [{'teamId': '1610612766',
#     'seasonStart': '2013',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612766',
#    'pickNum': '4',
#    'roundNum': '1',
#    'seasonYear': '2013'},
#   'nbaDebutYear': '2013',
#   'yearsPro': '5',
#   'collegeName': 'Indiana',
#   'lastAffiliation': 'Indiana/USA',
#   'country': 'USA'},
#  {'firstName': 'Tyler',
#   'lastName': 'Zeller',
#   'personId': '203092',
#   'teamId': '1610612749',
#   'jersey': '44',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '7',
#   'heightInches': '0',
#   'heightMeters': '2.13',
#   'weightPounds': '250',
#   'weightKilograms': '113.4',
#   'dateOfBirthUTC': '1990-01-17',
#   'teams': [{'teamId': '1610612739',
#     'seasonStart': '2012',
#     'seasonEnd': '2013'},
#    {'teamId': '1610612738', 'seasonStart': '2014', 'seasonEnd': '2016'},
#    {'teamId': '1610612751', 'seasonStart': '2017', 'seasonEnd': '2017'},
#    {'teamId': '1610612749', 'seasonStart': '2017', 'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612742',
#    'pickNum': '17',
#    'roundNum': '1',
#    'seasonYear': '2012'},
#   'nbaDebutYear': '2012',
#   'yearsPro': '6',
#   'collegeName': 'North Carolina',
#   'lastAffiliation': 'North Carolina/USA',
#   'country': 'USA'},
#  {'firstName': 'Fan',
#   'lastName': 'Zhang',
#   'personId': '1962937729',
#   'teamId': '15018',
#   'jersey': '',
#   'isActive': True,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Zhang',
#   'lastName': 'Zhaoxu',
#   'personId': '1962937766',
#   'teamId': '12329',
#   'jersey': '',
#   'isActive': True,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Luo',
#   'lastName': 'Zhi',
#   'personId': '1962937768',
#   'teamId': '12329',
#   'jersey': '',
#   'isActive': True,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Zheng',
#   'lastName': 'Zhun',
#   'personId': '27007',
#   'teamId': '15018',
#   'jersey': '50',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Liu',
#   'lastName': 'Zihao',
#   'personId': '27000',
#   'teamId': '15018',
#   'jersey': '25',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Tang',
#   'lastName': 'Zihao',
#   'personId': '1962937762',
#   'teamId': '12329',
#   'jersey': '',
#   'isActive': True,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Fan',
#   'lastName': 'Ziming',
#   'personId': '27009',
#   'teamId': '15018',
#   'jersey': '13',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Paul',
#   'lastName': 'Zipser',
#   'personId': '1627835',
#   'teamId': '1610612741',
#   'jersey': '16',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '226',
#   'weightKilograms': '102.5',
#   'dateOfBirthUTC': '1994-02-18',
#   'teams': [{'teamId': '1610612741',
#     'seasonStart': '2016',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612741',
#    'pickNum': '48',
#    'roundNum': '2',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '2',
#   'collegeName': '',
#   'lastAffiliation': 'Germany/Germany',
#   'country': 'Germany'},
#  {'firstName': 'Ante',
#   'lastName': 'Zizic',
#   'personId': '1627790',
#   'teamId': '1610612739',
#   'jersey': '41',
#   'isActive': True,
#   'pos': 'F-C',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '250',
#   'weightKilograms': '113.4',
#   'dateOfBirthUTC': '1997-01-04',
#   'teams': [{'teamId': '1610612739',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612738',
#    'pickNum': '23',
#    'roundNum': '1',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '1',
#   'collegeName': '',
#   'lastAffiliation': 'Croatia/Croatia',
#   'country': 'Croatia'},
#  {'firstName': 'Ivica',
#   'lastName': 'Zubac',
#   'personId': '1627826',
#   'teamId': '1610612747',
#   'jersey': '40',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '7',
#   'heightInches': '1',
#   'heightMeters': '2.16',
#   'weightPounds': '240',
#   'weightKilograms': '108.9',
#   'dateOfBirthUTC': '1997-03-18',
#   'teams': [{'teamId': '1610612747',
#     'seasonStart': '2016',
#     'seasonEnd': '2017'}],
#   'draft': {'teamId': '1610612747',
#    'pickNum': '32',
#    'roundNum': '2',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '2',
#   'collegeName': '',
#   'lastAffiliation': 'Mega Leks/Croatia',
#   'country': 'Croatia'}]

# %%
df = DataFrame(data_playerinfo)

# %%
df["heightMeters"] = pd.to_numeric(df["heightMeters"], errors = "coerce")
df.dropna(subset=["pos"])
height_group = df.groupby("pos")
count_height_group  = height_group["heightMeters"].mean()

# %%
df["weightKilograms"] = pd.to_numeric(df["weightKilograms"], errors = "coerce")
df.dropna(subset=["pos"])
weight_group = df.groupby("pos")
count_weight_group  = weight_group["weightKilograms"].mean()

# %%
df.loc[df['weightKilograms] == 115.7]
# Out:
#   File "<ipython-input-44-0749b6be6554>", line 1
#     df.loc[df['weightKilograms] == 115.7]
#                                          ^
# SyntaxError: EOL while scanning string literal
