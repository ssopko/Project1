# %%
import csv
import matplotlib.pyplot as plt
import openweathermapy as ow
import pandas as pd
import requests
import json
import numpy as np
from pandas import DataFrame
from pprint import pprint
from api_keys import api_key
print(api_key)
import requests
r = requests.get('https://api.mysportsfeeds.com/v2.0/pull/nba/2015-2016-regular/player_stats_totals.json', auth=(api_key, 'MYSPORTSFEEDS'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3f5ef6892caf> in <module>()
#       8 from pandas import DataFrame
#       9 from pprint import pprint
# ---> 10 from api_keys import api_key
#      11 print(api_key)
#      12 import requests
#
# ModuleNotFoundError: No module named 'api_keys'

# %%
data = r.json()
pprint(data)
# Out:
# {'lastUpdatedOn': '2019-01-09T22:51:49.452Z',
#  'playerStatsTotals': [{'player': {'age': 28,
#                                    'birthCity': 'Tyler, TX',
#                                    'birthCountry': 'USA',
#                                    'birthDate': '1990-10-05',
#                                    'college': 'Baylor University',
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'ROSTER',
#                                    'currentTeam': {'abbreviation': 'PHX',
#                                                    'id': 104},
#                                    'firstName': 'Quincy',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '6\'7"',
#                                    'highSchool': 'Mesquite Horn',
#                                    'id': 9466,
#                                    'jerseyNumber': 13,
#                                    'lastName': 'Acy',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'PF',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [{'mediaType': 'TWITTER',
#                                                             'value': 'QuincyAcy'}],
#                                    'weight': 240},
#                         'stats': {'defense': {'blk': 24,
#                                               'blkAgainst': 6,
#                                               'blkAgainstPerGame': 0.1,
#                                               'blkPerGame': 0.3,
#                                               'stl': 29,
#                                               'stlPerGame': 0.4,
#                                               'tov': 27,
#                                               'tovPerGame': 0.4},
#                                   'fieldGoals': {'fg2PtAtt': 165,
#                                                  'fg2PtAttPerGame': 2.4,
#                                                  'fg2PtMade': 100,
#                                                  'fg2PtMadePerGame': 1.4,
#                                                  'fg2PtPct': 60.6,
#                                                  'fg3PtAtt': 49,
#                                                  'fg3PtAttPerGame': 0.7,
#                                                  'fg3PtMade': 19,
#                                                  'fg3PtMadePerGame': 0.3,
#                                                  'fg3PtPct': 38.8,
#                                                  'fgAtt': 214,
#                                                  'fgAttPerGame': 3.1,
#                                                  'fgMade': 119,
#                                                  'fgMadePerGame': 1.7,
#                                                  'fgPct': 55.6},
#                                   'freeThrows': {'ftAtt': 68,
#                                                  'ftAttPerGame': 1.0,
#                                                  'ftMade': 50,
#                                                  'ftMadePerGame': 0.7,
#                                                  'ftPct': 73.5},
#                                   'gamesPlayed': 69,
#                                   'miscellaneous': {'foulPers': 103,
#                                                     'foulPersPerGame': 1.5,
#                                                     'minSeconds': 52555,
#                                                     'minSecondsPerGame': 761.7,
#                                                     'plusMinus': -129,
#                                                     'plusMinusPerGame': -1.9},
#                                   'offense': {'ast': 27,
#                                               'astPerGame': 0.4,
#                                               'pts': 307,
#                                               'ptsPerGame': 4.4},
#                                   'rebounds': {'defReb': 123,
#                                                'defRebPerGame': 1.8,
#                                                'offReb': 65,
#                                                'offRebPerGame': 0.9,
#                                                'reb': 188,
#                                                'rebPerGame': 2.7}},
#                         'team': {'abbreviation': 'SAC', 'id': 103}},
#                        {'player': {'age': 24,
#                                    'birthCity': 'Atlanta, GA',
#                                    'birthCountry': 'USA',
#                                    'birthDate': '1994-07-08',
#                                    'college': 'University of California, Los '
#                                               'Angeles',
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'RETIRED',
#                                    'currentTeam': None,
#                                    'firstName': 'Jordan',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '6\'5"',
#                                    'highSchool': 'Oak Hill Academy',
#                                    'id': 9301,
#                                    'jerseyNumber': 3,
#                                    'lastName': 'Adams',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'SG',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [{'mediaType': 'TWITTER',
#                                                             'value': 'jordanadams1231'}],
#                                    'weight': 209},
#                         'stats': {'defense': {'blk': 0,
#                                               'blkAgainst': 0,
#                                               'blkAgainstPerGame': 0.0,
#                                               'blkPerGame': 0.0,
#                                               'stl': 3,
#                                               'stlPerGame': 0.5,
#                                               'tov': 2,
#                                               'tovPerGame': 0.3},
#                                   'fieldGoals': {'fg2PtAtt': 5,
#                                                  'fg2PtAttPerGame': 0.8,
#                                                  'fg2PtMade': 2,
#                                                  'fg2PtMadePerGame': 0.3,
#                                                  'fg2PtPct': 40.0,
#                                                  'fg3PtAtt': 1,
#                                                  'fg3PtAttPerGame': 0.2,
#                                                  'fg3PtMade': 0,
#                                                  'fg3PtMadePerGame': 0.0,
#                                                  'fg3PtPct': 0.0,
#                                                  'fgAtt': 6,
#                                                  'fgAttPerGame': 1.0,
#                                                  'fgMade': 2,
#                                                  'fgMadePerGame': 0.3,
#                                                  'fgPct': 33.3},
#                                   'freeThrows': {'ftAtt': 5,
#                                                  'ftAttPerGame': 0.8,
#                                                  'ftMade': 3,
#                                                  'ftMadePerGame': 0.5,
#                                                  'ftPct': 60.0},
#                                   'gamesPlayed': 6,
#                                   'miscellaneous': {'foulPers': 2,
#                                                     'foulPersPerGame': 0.3,
#                                                     'minSeconds': 880,
#                                                     'minSecondsPerGame': 146.7,
#                                                     'plusMinus': 4,
#                                                     'plusMinusPerGame': 0.7},
#                                   'offense': {'ast': 3,
#                                               'astPerGame': 0.5,
#                                               'pts': 7,
#                                               'ptsPerGame': 1.2},
#                                   'rebounds': {'defReb': 2,
#                                                'defRebPerGame': 0.3,
#                                                'offReb': 0,
#                                                'offRebPerGame': 0.0,
#                                                'reb': 2,
#                                                'rebPerGame': 0.3}},
#                         'team': {'abbreviation': 'MEM', 'id': 107}},
#                        {'player': {'age': 25,
#                                    'birthCity': 'Rotorua',
#                                    'birthCountry': 'New Zealand',
#                                    'birthDate': '1993-07-20',
#                                    'college': 'University of Pittsburgh',
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'ROSTER',
#                                    'currentTeam': {'abbreviation': 'OKL',
#                                                    'id': 96},
#                                    'firstName': 'Steven',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '7\'0"',
#                                    'highSchool': 'Notre Dame Preparatory '
#                                                  'School',
#                                    'id': 9390,
#                                    'jerseyNumber': 12,
#                                    'lastName': 'Adams',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'C',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [{'mediaType': 'TWITTER',
#                                                             'value': 'RealStevenAdams'}],
#                                    'weight': 255},
#                         'stats': {'defense': {'blk': 89,
#                                               'blkAgainst': 31,
#                                               'blkAgainstPerGame': 0.4,
#                                               'blkPerGame': 1.1,
#                                               'stl': 42,
#                                               'stlPerGame': 0.5,
#                                               'tov': 84,
#                                               'tovPerGame': 1.0},
#                                   'fieldGoals': {'fg2PtAtt': 426,
#                                                  'fg2PtAttPerGame': 5.3,
#                                                  'fg2PtMade': 261,
#                                                  'fg2PtMadePerGame': 3.2,
#                                                  'fg2PtPct': 61.3,
#                                                  'fg3PtAtt': 0,
#                                                  'fg3PtAttPerGame': 0.0,
#                                                  'fg3PtMade': 0,
#                                                  'fg3PtMadePerGame': 0.0,
#                                                  'fg3PtPct': 0.0,
#                                                  'fgAtt': 426,
#                                                  'fgAttPerGame': 5.3,
#                                                  'fgMade': 261,
#                                                  'fgMadePerGame': 3.2,
#                                                  'fgPct': 61.3},
#                                   'freeThrows': {'ftAtt': 196,
#                                                  'ftAttPerGame': 2.4,
#                                                  'ftMade': 114,
#                                                  'ftMadePerGame': 1.4,
#                                                  'ftPct': 58.2},
#                                   'gamesPlayed': 81,
#                                   'miscellaneous': {'foulPers': 221,
#                                                     'foulPersPerGame': 2.7,
#                                                     'minSeconds': 120863,
#                                                     'minSecondsPerGame': 1492.1,
#                                                     'plusMinus': 478,
#                                                     'plusMinusPerGame': 5.9},
#                                   'offense': {'ast': 62,
#                                               'astPerGame': 0.8,
#                                               'pts': 636,
#                                               'ptsPerGame': 7.9},
#                                   'rebounds': {'defReb': 315,
#                                                'defRebPerGame': 3.9,
#                                                'offReb': 218,
#                                                'offRebPerGame': 2.7,
#                                                'reb': 533,
#                                                'rebPerGame': 6.6}},
#                         'team': {'abbreviation': 'OKL', 'id': 96}},
#                        {'player': {'age': 33,
#                                    'birthCity': 'Los Angeles, CA',
#                                    'birthCountry': 'USA',
#                                    'birthDate': '1985-10-15',
#                                    'college': 'University of California, Los '
#                                               'Angeles',
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'ROSTER',
#                                    'currentTeam': {'abbreviation': 'ORL',
#                                                    'id': 95},
#                                    'firstName': 'Arron',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '6\'5"',
#                                    'highSchool': 'Centennial',
#                                    'id': 9375,
#                                    'jerseyNumber': 4,
#                                    'lastName': 'Afflalo',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'SG',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [],
#                                    'weight': 210},
#                         'stats': {'defense': {'blk': 10,
#                                               'blkAgainst': 47,
#                                               'blkAgainstPerGame': 0.6,
#                                               'blkPerGame': 0.1,
#                                               'stl': 25,
#                                               'stlPerGame': 0.3,
#                                               'tov': 82,
#                                               'tovPerGame': 1.1},
#                                   'fieldGoals': {'fg2PtAtt': 561,
#                                                  'fg2PtAttPerGame': 7.7,
#                                                  'fg2PtMade': 263,
#                                                  'fg2PtMadePerGame': 3.6,
#                                                  'fg2PtPct': 46.9,
#                                                  'fg3PtAtt': 238,
#                                                  'fg3PtAttPerGame': 3.3,
#                                                  'fg3PtMade': 91,
#                                                  'fg3PtMadePerGame': 1.2,
#                                                  'fg3PtPct': 38.2,
#                                                  'fgAtt': 799,
#                                                  'fgAttPerGame': 10.9,
#                                                  'fgMade': 354,
#                                                  'fgMadePerGame': 4.8,
#                                                  'fgPct': 44.3},
#                                   'freeThrows': {'ftAtt': 131,
#                                                  'ftAttPerGame': 1.8,
#                                                  'ftMade': 110,
#                                                  'ftMadePerGame': 1.5,
#                                                  'ftPct': 84.0},
#                                   'gamesPlayed': 73,
#                                   'miscellaneous': {'foulPers': 142,
#                                                     'foulPersPerGame': 1.9,
#                                                     'minSeconds': 142256,
#                                                     'minSecondsPerGame': 1948.7,
#                                                     'plusMinus': -149,
#                                                     'plusMinusPerGame': -2.0},
#                                   'offense': {'ast': 144,
#                                               'astPerGame': 2.0,
#                                               'pts': 909,
#                                               'ptsPerGame': 12.5},
#                                   'rebounds': {'defReb': 243,
#                                                'defRebPerGame': 3.3,
#                                                'offReb': 23,
#                                                'offRebPerGame': 0.3,
#                                                'reb': 266,
#                                                'rebPerGame': 3.6}},
#                         'team': {'abbreviation': 'NYK', 'id': 83}},
#                        {'player': {'age': 30,
#                                    'birthCity': 'Saint-Etienne',
#                                    'birthCountry': 'France',
#                                    'birthDate': '1988-05-06',
#                                    'college': None,
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'ROSTER',
#                                    'currentTeam': {'abbreviation': 'NOP',
#                                                    'id': 110},
#                                    'firstName': 'Alexis',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '7\'2"',
#                                    'highSchool': None,
#                                    'id': 9357,
#                                    'jerseyNumber': 42,
#                                    'lastName': 'Ajinca',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'C',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [],
#                                    'weight': 248},
#                         'stats': {'defense': {'blk': 36,
#                                               'blkAgainst': 12,
#                                               'blkAgainstPerGame': 0.2,
#                                               'blkPerGame': 0.5,
#                                               'stl': 19,
#                                               'stlPerGame': 0.3,
#                                               'tov': 54,
#                                               'tovPerGame': 0.8},
#                                   'fieldGoals': {'fg2PtAtt': 314,
#                                                  'fg2PtAttPerGame': 4.7,
#                                                  'fg2PtMade': 150,
#                                                  'fg2PtMadePerGame': 2.2,
#                                                  'fg2PtPct': 47.8,
#                                                  'fg3PtAtt': 1,
#                                                  'fg3PtAttPerGame': 0.0,
#                                                  'fg3PtMade': 0,
#                                                  'fg3PtMadePerGame': 0.0,
#                                                  'fg3PtPct': 0.0,
#                                                  'fgAtt': 315,
#                                                  'fgAttPerGame': 4.7,
#                                                  'fgMade': 150,
#                                                  'fgMadePerGame': 2.2,
#                                                  'fgPct': 47.6},
#                                   'freeThrows': {'ftAtt': 62,
#                                                  'ftAttPerGame': 0.9,
#                                                  'ftMade': 52,
#                                                  'ftMadePerGame': 0.8,
#                                                  'ftPct': 83.9},
#                                   'gamesPlayed': 67,
#                                   'miscellaneous': {'foulPers': 133,
#                                                     'foulPersPerGame': 2.0,
#                                                     'minSeconds': 51643,
#                                                     'minSecondsPerGame': 770.8,
#                                                     'plusMinus': -65,
#                                                     'plusMinusPerGame': -1.0},
#                                   'offense': {'ast': 31,
#                                               'astPerGame': 0.5,
#                                               'pts': 352,
#                                               'ptsPerGame': 5.3},
#                                   'rebounds': {'defReb': 194,
#                                                'defRebPerGame': 2.9,
#                                                'offReb': 75,
#                                                'offRebPerGame': 1.1,
#                                                'reb': 269,
#                                                'rebPerGame': 4.0}},
#                         'team': {'abbreviation': 'NOP', 'id': 110}},
#                        {'player': {'age': 30,
#                                    'birthCity': 'Burnsville, MN',
#                                    'birthCountry': 'USA',
#                                    'birthDate': '1988-10-31',
#                                    'college': 'University of Kansas',
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'ROSTER',
#                                    'currentTeam': {'abbreviation': 'MIN',
#                                                    'id': 100},
#                                    'firstName': 'Cole',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '6\'11"',
#                                    'highSchool': 'Thomas Jefferson',
#                                    'id': 9272,
#                                    'jerseyNumber': 45,
#                                    'lastName': 'Aldrich',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'C',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [{'mediaType': 'TWITTER',
#                                                             'value': 'colea45'}],
#                                    'weight': 253},
#                         'stats': {'defense': {'blk': 68,
#                                               'blkAgainst': 18,
#                                               'blkAgainstPerGame': 0.3,
#                                               'blkPerGame': 1.0,
#                                               'stl': 47,
#                                               'stlPerGame': 0.7,
#                                               'tov': 64,
#                                               'tovPerGame': 1.0},
#                                   'fieldGoals': {'fg2PtAtt': 225,
#                                                  'fg2PtAttPerGame': 3.4,
#                                                  'fg2PtMade': 134,
#                                                  'fg2PtMadePerGame': 2.0,
#                                                  'fg2PtPct': 59.6,
#                                                  'fg3PtAtt': 0,
#                                                  'fg3PtAttPerGame': 0.0,
#                                                  'fg3PtMade': 0,
#                                                  'fg3PtMadePerGame': 0.0,
#                                                  'fg3PtPct': 0.0,
#                                                  'fgAtt': 225,
#                                                  'fgAttPerGame': 3.4,
#                                                  'fgMade': 134,
#                                                  'fgMadePerGame': 2.0,
#                                                  'fgPct': 59.6},
#                                   'freeThrows': {'ftAtt': 84,
#                                                  'ftAttPerGame': 1.3,
#                                                  'ftMade': 60,
#                                                  'ftMadePerGame': 0.9,
#                                                  'ftPct': 71.4},
#                                   'gamesPlayed': 66,
#                                   'miscellaneous': {'foulPers': 139,
#                                                     'foulPersPerGame': 2.1,
#                                                     'minSeconds': 47984,
#                                                     'minSecondsPerGame': 727.0,
#                                                     'plusMinus': -26,
#                                                     'plusMinusPerGame': -0.4},
#                                   'offense': {'ast': 50,
#                                               'astPerGame': 0.8,
#                                               'pts': 328,
#                                               'ptsPerGame': 5.0},
#                                   'rebounds': {'defReb': 202,
#                                                'defRebPerGame': 3.1,
#                                                'offReb': 86,
#                                                'offRebPerGame': 1.3,
#                                                'reb': 288,
#                                                'rebPerGame': 4.4}},
#                         'team': {'abbreviation': 'LAC', 'id': 102}},
#                        {'player': {'age': 33,
#                                    'birthCity': 'Dallas, TX',
#                                    'birthCountry': 'USA',
#                                    'birthDate': '1985-07-19',
#                                    'college': 'University of Texas at Austin',
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'ROSTER',
#                                    'currentTeam': {'abbreviation': 'SAS',
#                                                    'id': 106},
#                                    'firstName': 'LaMarcus',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '6\'11"',
#                                    'highSchool': 'Seagoville',
#                                    'id': 9480,
#                                    'jerseyNumber': 12,
#                                    'lastName': 'Aldridge',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'PF',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [{'mediaType': 'TWITTER',
#                                                             'value': 'aldridge_12'}],
#                                    'weight': 260},
#                         'stats': {'defense': {'blk': 81,
#                                               'blkAgainst': 37,
#                                               'blkAgainstPerGame': 0.5,
#                                               'blkPerGame': 1.0,
#                                               'stl': 38,
#                                               'stlPerGame': 0.5,
#                                               'tov': 99,
#                                               'tovPerGame': 1.2},
#                                   'fieldGoals': {'fg2PtAtt': 1029,
#                                                  'fg2PtAttPerGame': 12.7,
#                                                  'fg2PtMade': 536,
#                                                  'fg2PtMadePerGame': 6.6,
#                                                  'fg2PtPct': 52.1,
#                                                  'fg3PtAtt': 16,
#                                                  'fg3PtAttPerGame': 0.2,
#                                                  'fg3PtMade': 0,
#                                                  'fg3PtMadePerGame': 0.0,
#                                                  'fg3PtPct': 0.0,
#                                                  'fgAtt': 1045,
#                                                  'fgAttPerGame': 12.9,
#                                                  'fgMade': 536,
#                                                  'fgMadePerGame': 6.6,
#                                                  'fgPct': 51.3},
#                                   'freeThrows': {'ftAtt': 302,
#                                                  'ftAttPerGame': 3.7,
#                                                  'ftMade': 259,
#                                                  'ftMadePerGame': 3.2,
#                                                  'ftPct': 85.8},
#                                   'gamesPlayed': 81,
#                                   'miscellaneous': {'foulPers': 151,
#                                                     'foulPersPerGame': 1.9,
#                                                     'minSeconds': 135658,
#                                                     'minSecondsPerGame': 1674.8,
#                                                     'plusMinus': 507,
#                                                     'plusMinusPerGame': 6.3},
#                                   'offense': {'ast': 110,
#                                               'astPerGame': 1.4,
#                                               'pts': 1331,
#                                               'ptsPerGame': 16.4},
#                                   'rebounds': {'defReb': 456,
#                                                'defRebPerGame': 5.6,
#                                                'offReb': 175,
#                                                'offRebPerGame': 2.2,
#                                                'reb': 632,
#                                                'rebPerGame': 7.8}},
#                         'team': {'abbreviation': 'SAS', 'id': 106}},
#                        {'player': {'age': 23,
#                                    'birthCity': 'Chicago, IL',
#                                    'birthCountry': 'USA',
#                                    'birthDate': '1995-11-16',
#                                    'college': 'University of Kansas',
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'RETIRED',
#                                    'currentTeam': {'abbreviation': 'ORL',
#                                                    'id': 95},
#                                    'firstName': 'Cliff',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '6\'8"',
#                                    'highSchool': 'Curie',
#                                    'id': 9454,
#                                    'jerseyNumber': 34,
#                                    'lastName': 'Alexander',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'PF',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [],
#                                    'weight': 240},
#                         'stats': {'defense': {'blk': 2,
#                                               'blkAgainst': 1,
#                                               'blkAgainstPerGame': 0.1,
#                                               'blkPerGame': 0.2,
#                                               'stl': 1,
#                                               'stlPerGame': 0.1,
#                                               'tov': 1,
#                                               'tovPerGame': 0.1},
#                                   'fieldGoals': {'fg2PtAtt': 10,
#                                                  'fg2PtAttPerGame': 0.8,
#                                                  'fg2PtMade': 5,
#                                                  'fg2PtMadePerGame': 0.4,
#                                                  'fg2PtPct': 50.0,
#                                                  'fg3PtAtt': 0,
#                                                  'fg3PtAttPerGame': 0.0,
#                                                  'fg3PtMade': 0,
#                                                  'fg3PtMadePerGame': 0.0,
#                                                  'fg3PtPct': 0.0,
#                                                  'fgAtt': 10,
#                                                  'fgAttPerGame': 0.8,
#                                                  'fgMade': 5,
#                                                  'fgMadePerGame': 0.4,
#                                                  'fgPct': 50.0},
#                                   'freeThrows': {'ftAtt': 0,
#                                                  'ftAttPerGame': 0.0,
#                                                  'ftMade': 0,
#                                                  'ftMadePerGame': 0.0,
#                                                  'ftPct': 0.0},
#                                   'gamesPlayed': 13,
#                                   'miscellaneous': {'foulPers': 1,
#                                                     'foulPersPerGame': 0.1,
#                                                     'minSeconds': 2158,
#                                                     'minSecondsPerGame': 166.0,
#                                                     'plusMinus': -13,
#                                                     'plusMinusPerGame': -1.0},
#                                   'offense': {'ast': 0,
#                                               'astPerGame': 0.0,
#                                               'pts': 10,
#                                               'ptsPerGame': 0.8},
#                                   'rebounds': {'defReb': 4,
#                                                'defRebPerGame': 0.3,
#                                                'offReb': 2,
#                                                'offRebPerGame': 0.2,
#                                                'reb': 6,
#                                                'rebPerGame': 0.5}},
#                         'team': {'abbreviation': 'POR', 'id': 97}},
#                        {'player': {'age': 29,
#                                    'birthCity': 'Morrisville, PA',
#                                    'birthCountry': 'USA',
#                                    'birthDate': '1989-02-04',
#                                    'college': 'Temple University',
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'UFA',
#                                    'currentTeam': None,
#                                    'firstName': 'Lavoy',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '6\'9"',
#                                    'highSchool': 'Pennsbury',
#                                    'id': 9254,
#                                    'jerseyNumber': 5,
#                                    'lastName': 'Allen',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'PF',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [],
#                                    'weight': 260},
#                         'stats': {'defense': {'blk': 42,
#                                               'blkAgainst': 22,
#                                               'blkAgainstPerGame': 0.3,
#                                               'blkPerGame': 0.5,
#                                               'stl': 26,
#                                               'stlPerGame': 0.3,
#                                               'tov': 69,
#                                               'tovPerGame': 0.8},
#                                   'fieldGoals': {'fg2PtAtt': 370,
#                                                  'fg2PtAttPerGame': 4.5,
#                                                  'fg2PtMade': 191,
#                                                  'fg2PtMadePerGame': 2.3,
#                                                  'fg2PtPct': 51.6,
#                                                  'fg3PtAtt': 0,
#                                                  'fg3PtAttPerGame': 0.0,
#                                                  'fg3PtMade': 0,
#                                                  'fg3PtMadePerGame': 0.0,
#                                                  'fg3PtPct': 0.0,
#                                                  'fgAtt': 370,
#                                                  'fgAttPerGame': 4.5,
#                                                  'fgMade': 191,
#                                                  'fgMadePerGame': 2.3,
#                                                  'fgPct': 51.6},
#                                   'freeThrows': {'ftAtt': 73,
#                                                  'ftAttPerGame': 0.9,
#                                                  'ftMade': 46,
#                                                  'ftMadePerGame': 0.6,
#                                                  'ftPct': 63.0},
#                                   'gamesPlayed': 82,
#                                   'miscellaneous': {'foulPers': 147,
#                                                     'foulPersPerGame': 1.8,
#                                                     'minSeconds': 95931,
#                                                     'minSecondsPerGame': 1169.9,
#                                                     'plusMinus': 191,
#                                                     'plusMinusPerGame': 2.3},
#                                   'offense': {'ast': 76,
#                                               'astPerGame': 0.9,
#                                               'pts': 428,
#                                               'ptsPerGame': 5.2},
#                                   'rebounds': {'defReb': 262,
#                                                'defRebPerGame': 3.2,
#                                                'offReb': 162,
#                                                'offRebPerGame': 2.0,
#                                                'reb': 424,
#                                                'rebPerGame': 5.2}},
#                         'team': {'abbreviation': 'IND', 'id': 87}},
#                        {'player': {'age': 36,
#                                    'birthCity': 'Chicago, IL',
#                                    'birthCountry': 'USA',
#                                    'birthDate': '1982-01-10',
#                                    'college': 'Oklahoma State University',
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'ROSTER',
#                                    'currentTeam': {'abbreviation': 'CHI',
#                                                    'id': 89},
#                                    'firstName': 'Tony',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '6\'4"',
#                                    'highSchool': 'Crane Technical Preparatory',
#                                    'id': 9299,
#                                    'jerseyNumber': 9,
#                                    'lastName': 'Allen',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'SF',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [{'mediaType': 'TWITTER',
#                                                             'value': 'aa000G9'}],
#                                    'weight': 213},
#                         'stats': {'defense': {'blk': 18,
#                                               'blkAgainst': 59,
#                                               'blkAgainstPerGame': 0.9,
#                                               'blkPerGame': 0.3,
#                                               'stl': 110,
#                                               'stlPerGame': 1.6,
#                                               'tov': 78,
#                                               'tovPerGame': 1.1},
#                                   'fieldGoals': {'fg2PtAtt': 427,
#                                                  'fg2PtAttPerGame': 6.2,
#                                                  'fg2PtMade': 200,
#                                                  'fg2PtMadePerGame': 2.9,
#                                                  'fg2PtPct': 46.8,
#                                                  'fg3PtAtt': 42,
#                                                  'fg3PtAttPerGame': 0.6,
#                                                  'fg3PtMade': 15,
#                                                  'fg3PtMadePerGame': 0.2,
#                                                  'fg3PtPct': 35.7,
#                                                  'fgAtt': 469,
#                                                  'fgAttPerGame': 6.8,
#                                                  'fgMade': 215,
#                                                  'fgMadePerGame': 3.1,
#                                                  'fgPct': 45.8},
#                                   'freeThrows': {'ftAtt': 138,
#                                                  'ftAttPerGame': 2.0,
#                                                  'ftMade': 90,
#                                                  'ftMadePerGame': 1.3,
#                                                  'ftPct': 65.2},
#                                   'gamesPlayed': 69,
#                                   'miscellaneous': {'foulPers': 174,
#                                                     'foulPersPerGame': 2.5,
#                                                     'minSeconds': 97192,
#                                                     'minSecondsPerGame': 1408.6,
#                                                     'plusMinus': -92,
#                                                     'plusMinusPerGame': -1.3},
#                                   'offense': {'ast': 70,
#                                               'astPerGame': 1.0,
#                                               'pts': 535,
#                                               'ptsPerGame': 7.8},
#                                   'rebounds': {'defReb': 192,
#                                                'defRebPerGame': 2.8,
#                                                'offReb': 104,
#                                                'offRebPerGame': 1.5,
#                                                'reb': 296,
#                                                'rebPerGame': 4.3}},
#                         'team': {'abbreviation': 'MEM', 'id': 107}},
#                        {'player': {'age': 28,
#                                    'birthCity': 'Atlanta, GA',
#                                    'birthCountry': 'USA',
#                                    'birthDate': '1990-09-21',
#                                    'college': 'Wake Forest University',
#                                    'currentInjury': None,
#                                    'currentRosterStatus': 'ROSTER',
#                                    'currentTeam': {'abbreviation': 'POR',
#                                                    'id': 97},
#                                    'firstName': 'Al-Farouq',
#                                    'handedness': {'shoots': 'R'},
#                                    'height': '6\'9"',
#                                    'highSchool': 'Norcross',
#                                    'id': 9452,
#                                    'jerseyNumber': 8,
#                                    'lastName': 'Aminu',
#                                    'officialImageSrc': None,
#                                    'primaryPosition': 'PF',
#                                    'rookie': False,
#                                    'socialMediaAccounts': [{'mediaType': 'TWITTER',
#                                                             'value': 'farouq1'}],
#                                    'weight': 220},
#                         'stats': {'defense': {'blk': 53,
#                                               'blkAgainst': 35,
#                                               'blkAgainstPerGame': 0.4,
#                                               'blkPerGame': 0.6,
#                                               'stl': 72,
#                                               'stlPerGame': 0.9,
#                                               'tov': 120,
#                                               'tovPerGame': 1.5},
#                                   'fieldGoals': {'fg2PtAtt': 370,
#                                                  'fg2PtAttPerGame': 4.5,
#                                                  'fg2PtMade': 173,
#                                                  'fg2PtMadePerGame': 2.1,
#                                                  'fg2PtPct': 46.8,
#                                                  'fg3PtAtt': 349,
#                                                  'fg3PtAttPerGame': 4.3,
#                                                  'fg3PtMade': 126,
#                                                  'fg3PtMadePerGame': 1.5,
#                                                  'fg3PtPct': 36.1,
#                                                  'fgAtt': 719,
#                                                  'fgAttPerGame': 8.8,
#                                                  'fgMade': 299,
#                                                  'fgMadePerGame': 3.6,
#                                                  'fgPct': 41.6},
#                                   'freeThrows': {'ftAtt': 156,
#                                                  'ftAttPerGame': 1.9,
#                                                  'ftMade': 115,
#                                                  'ftMadePerGame': 1.4,
#                                                  'ftPct': 73.7},
#                                   'gamesPlayed': 82,
#                                   'miscellaneous': {'foulPers': 171,
#                                                     'foulPersPerGame': 2.1,
#                                                     'minSeconds': 140452,
#                                                     'minSecondsPerGame': 1712.8,
#                                                     'plusMinus': 58,
#                                                     'plusMinusPerGame': 0.7},
#                                   'offense': {'ast': 138,
#                                               'astPerGame': 1.7,
#                                               'pts': 839,
#                                               'ptsPerGame': 10.2},
#                                   'rebounds': {'defReb': 401,
#                                                'defRebPerGame': 4.9,
#                                                'offReb': 97,
# ...
#                                    {'abbreviation': 'NYK',
#                                     'city': 'New York',
#                                     'homeVenue': {'id': 12,
#                                                   'name': 'Madison Square '
#                                                           'Garden'},
#                                     'id': 83,
#                                     'name': 'Knicks',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'BRO',
#                                     'city': 'Brooklyn',
#                                     'homeVenue': {'id': 78,
#                                                   'name': 'Barclays Center'},
#                                     'id': 84,
#                                     'name': 'Nets',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'PHI',
#                                     'city': 'Philadelphia',
#                                     'homeVenue': {'id': 29,
#                                                   'name': 'Wells Fargo Center'},
#                                     'id': 85,
#                                     'name': '76ers',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'CLE',
#                                     'city': 'Cleveland',
#                                     'homeVenue': {'id': 80,
#                                                   'name': 'Quicken Loans '
#                                                           'Arena'},
#                                     'id': 86,
#                                     'name': 'Cavaliers',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'IND',
#                                     'city': 'Indiana',
#                                     'homeVenue': {'id': 81,
#                                                   'name': 'Bankers Life '
#                                                           'Fieldhouse'},
#                                     'id': 87,
#                                     'name': 'Pacers',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'DET',
#                                     'city': 'Detroit',
#                                     'homeVenue': {'id': 82,
#                                                   'name': 'The Palace of '
#                                                           'Auburn Hills'},
#                                     'id': 88,
#                                     'name': 'Pistons',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'CHI',
#                                     'city': 'Chicago',
#                                     'homeVenue': {'id': 28,
#                                                   'name': 'United Center'},
#                                     'id': 89,
#                                     'name': 'Bulls',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'MIL',
#                                     'city': 'Milwaukee',
#                                     'homeVenue': {'id': 84,
#                                                   'name': 'BMO Bradley Harris '
#                                                           'Center'},
#                                     'id': 90,
#                                     'name': 'Bucks',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'ATL',
#                                     'city': 'Atlanta',
#                                     'homeVenue': {'id': 20,
#                                                   'name': 'Philips Arena'},
#                                     'id': 91,
#                                     'name': 'Hawks',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'MIA',
#                                     'city': 'Miami',
#                                     'homeVenue': {'id': 86,
#                                                   'name': 'American Airlines '
#                                                           'Arena'},
#                                     'id': 92,
#                                     'name': 'Heat',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'CHA',
#                                     'city': 'Charlotte',
#                                     'homeVenue': {'id': 87,
#                                                   'name': 'Time Warner Cable '
#                                                           'Arena'},
#                                     'id': 93,
#                                     'name': 'Hornets',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'WAS',
#                                     'city': 'Washington',
#                                     'homeVenue': {'id': 13,
#                                                   'name': 'Verizon Center'},
#                                     'id': 94,
#                                     'name': 'Wizards',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'ORL',
#                                     'city': 'Orlando',
#                                     'homeVenue': {'id': 89,
#                                                   'name': 'Amway Center'},
#                                     'id': 95,
#                                     'name': 'Magic',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'OKL',
#                                     'city': 'Oklahoma City',
#                                     'homeVenue': {'id': 90,
#                                                   'name': 'Chesapeake Energy '
#                                                           'Arena'},
#                                     'id': 96,
#                                     'name': 'Thunder',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'POR',
#                                     'city': 'Portland',
#                                     'homeVenue': {'id': 91,
#                                                   'name': 'Moda Center'},
#                                     'id': 97,
#                                     'name': 'Trail Blazers',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'UTA',
#                                     'city': 'Utah',
#                                     'homeVenue': {'id': 92,
#                                                   'name': 'Vivint Smart Home '
#                                                           'Arena'},
#                                     'id': 98,
#                                     'name': 'Jazz',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'DEN',
#                                     'city': 'Denver',
#                                     'homeVenue': {'id': 19,
#                                                   'name': 'Pepsi Center'},
#                                     'id': 99,
#                                     'name': 'Nuggets',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'MIN',
#                                     'city': 'Minnesota',
#                                     'homeVenue': {'id': 94,
#                                                   'name': 'Target Center'},
#                                     'id': 100,
#                                     'name': 'Timberwolves',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'GSW',
#                                     'city': 'Golden State',
#                                     'homeVenue': {'id': 95,
#                                                   'name': 'Oracle Arena'},
#                                     'id': 101,
#                                     'name': 'Warriors',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'LAC',
#                                     'city': 'Los Angeles',
#                                     'homeVenue': {'id': 25,
#                                                   'name': 'Staples Center'},
#                                     'id': 102,
#                                     'name': 'Clippers',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'SAC',
#                                     'city': 'Sacramento',
#                                     'homeVenue': {'id': 97,
#                                                   'name': 'Sleep Train Arena'},
#                                     'id': 103,
#                                     'name': 'Kings',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'PHX',
#                                     'city': 'Phoenix',
#                                     'homeVenue': {'id': 98,
#                                                   'name': 'Talking Stick '
#                                                           'Resort Arena'},
#                                     'id': 104,
#                                     'name': 'Suns',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'LAL',
#                                     'city': 'Los Angeles',
#                                     'homeVenue': {'id': 25,
#                                                   'name': 'Staples Center'},
#                                     'id': 105,
#                                     'name': 'Lakers',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'SAS',
#                                     'city': 'San Antonio',
#                                     'homeVenue': {'id': 99,
#                                                   'name': 'AT&T Center'},
#                                     'id': 106,
#                                     'name': 'Spurs',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'MEM',
#                                     'city': 'Memphis',
#                                     'homeVenue': {'id': 100,
#                                                   'name': 'FedEx Forum'},
#                                     'id': 107,
#                                     'name': 'Grizzlies',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'DAL',
#                                     'city': 'Dallas',
#                                     'homeVenue': {'id': 2,
#                                                   'name': 'American Airlines '
#                                                           'Center'},
#                                     'id': 108,
#                                     'name': 'Mavericks',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'HOU',
#                                     'city': 'Houston',
#                                     'homeVenue': {'id': 102,
#                                                   'name': 'Toyota Center'},
#                                     'id': 109,
#                                     'name': 'Rockets',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []},
#                                    {'abbreviation': 'NOP',
#                                     'city': 'New Orleans',
#                                     'homeVenue': {'id': 103,
#                                                   'name': 'Smoothie King '
#                                                           'Center'},
#                                     'id': 110,
#                                     'name': 'Pelicans',
#                                     'officialLogoImageSrc': None,
#                                     'socialMediaAccounts': [],
#                                     'teamColoursHex': []}]}}

# %%
# We're going to need regular expressions now;
# import the re module
import re

# Convert prime-notation height to inches
def inches(prime_str):
    ## Wrap the function in try/except
    try: 
        # Extract feet and inches from the string, as long as 
        # 1. feet is a numeric value at the start of the string, followed
        # by a single prime mark
        # 2. inches is a numeric value preceded by the feet and single prime
        # mark and optionally followed by a double prime mark
        result = re.match(r"(?P[0-9]+)\'(?P[0-9]{0,2}?)[\"]?\Z", prime_str)
    
        # Access the extract values using the .group() method
        feet = int(result.group(1))
        if result.group(2) == "":
            inches = 0
        else:
            inches = int(result.group(2))
        # print "Feet: ", feet 
        # print "Inches: ", inches
    except:
        # This code will only be called if the code within the try: block
        # throws an exception
        return None

    # We won't get to this point unless the code in the try block was successful
        
    return feet * 12 + inches

# %%
players = []
for x in data['playerStatsTotals']:
    players.append(x['player'])

stats = []
for x in data['playerStatsTotals']:
    stats.append(x['stats'])

# %%
df = DataFrame(players)
df1 = DataFrame(stats)
df.head()
# Out:
#    age        birthCity birthCountry   birthDate  \
# 0   28        Tyler, TX          USA  1990-10-05
# 1   24      Atlanta, GA          USA  1994-07-08
# 2   25          Rotorua  New Zealand  1993-07-20
# 3   33  Los Angeles, CA          USA  1985-10-15
# 4   30    Saint-Etienne       France  1988-05-06
#
#                                  college currentInjury currentRosterStatus  \
# 0                      Baylor University          None              ROSTER
# 1  University of California, Los Angeles          None             RETIRED
# 2               University of Pittsburgh          None              ROSTER
# 3  University of California, Los Angeles          None              ROSTER
# 4                                   None          None              ROSTER
#
#                           currentTeam firstName       handedness height  \
# 0  {'id': 104, 'abbreviation': 'PHX'}    Quincy  {'shoots': 'R'}   6'7"
# 1                                None    Jordan  {'shoots': 'R'}   6'5"
# 2   {'id': 96, 'abbreviation': 'OKL'}    Steven  {'shoots': 'R'}   7'0"
# 3   {'id': 95, 'abbreviation': 'ORL'}     Arron  {'shoots': 'R'}   6'5"
# 4  {'id': 110, 'abbreviation': 'NOP'}    Alexis  {'shoots': 'R'}   7'2"
#
#                       highSchool    id  jerseyNumber lastName  \
# 0                  Mesquite Horn  9466          13.0      Acy
# 1               Oak Hill Academy  9301           3.0    Adams
# 2  Notre Dame Preparatory School  9390          12.0    Adams
# 3                     Centennial  9375           4.0  Afflalo
# 4                           None  9357          42.0   Ajinca
#
#   officialImageSrc primaryPosition  rookie  \
# 0             None              PF   False
# 1             None              SG   False
# 2             None               C   False
# 3             None              SG   False
# 4             None               C   False
#
#                                  socialMediaAccounts  weight
# 0   [{'mediaType': 'TWITTER', 'value': 'QuincyAcy'}]   240.0
# 1  [{'mediaType': 'TWITTER', 'value': 'jordanadam...   209.0
# 2  [{'mediaType': 'TWITTER', 'value': 'RealSteven...   255.0
# 3                                                 []   210.0
# 4                                                 []   248.0

# %%
df["height"] = df["height"].apply(inches)
df.head()
# Out:
#    age        birthCity birthCountry   birthDate  \
# 0   28        Tyler, TX          USA  1990-10-05
# 1   24      Atlanta, GA          USA  1994-07-08
# 2   25          Rotorua  New Zealand  1993-07-20
# 3   33  Los Angeles, CA          USA  1985-10-15
# 4   30    Saint-Etienne       France  1988-05-06
#
#                                  college currentInjury currentRosterStatus  \
# 0                      Baylor University          None              ROSTER
# 1  University of California, Los Angeles          None             RETIRED
# 2               University of Pittsburgh          None              ROSTER
# 3  University of California, Los Angeles          None              ROSTER
# 4                                   None          None              ROSTER
#
#                           currentTeam firstName       handedness height  \
# 0  {'id': 104, 'abbreviation': 'PHX'}    Quincy  {'shoots': 'R'}   None
# 1                                None    Jordan  {'shoots': 'R'}   None
# 2   {'id': 96, 'abbreviation': 'OKL'}    Steven  {'shoots': 'R'}   None
# 3   {'id': 95, 'abbreviation': 'ORL'}     Arron  {'shoots': 'R'}   None
# 4  {'id': 110, 'abbreviation': 'NOP'}    Alexis  {'shoots': 'R'}   None
#
#                       highSchool    id  jerseyNumber lastName  \
# 0                  Mesquite Horn  9466          13.0      Acy
# 1               Oak Hill Academy  9301           3.0    Adams
# 2  Notre Dame Preparatory School  9390          12.0    Adams
# 3                     Centennial  9375           4.0  Afflalo
# 4                           None  9357          42.0   Ajinca
#
#   officialImageSrc primaryPosition  rookie  \
# 0             None              PF   False
# 1             None              SG   False
# 2             None               C   False
# 3             None              SG   False
# 4             None               C   False
#
#                                  socialMediaAccounts  weight
# 0   [{'mediaType': 'TWITTER', 'value': 'QuincyAcy'}]   240.0
# 1  [{'mediaType': 'TWITTER', 'value': 'jordanadam...   209.0
# 2  [{'mediaType': 'TWITTER', 'value': 'RealSteven...   255.0
# 3                                                 []   210.0
# 4                                                 []   248.0
