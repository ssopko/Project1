# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame

# %%
file = 'nba.csv'

# %%
df = pd.read_csv(file, encoding="utf-8")
test = df.describe()
test
df
# Out:
#                      Teams   2000   2001   2002   2003   2004   2005   2006  \
# 0           Atlantic Hawks  0.305  0.402  0.427  0.341  0.159  0.317  0.366
# 1           Boston Celtics  0.439  0.598  0.537  0.439  0.549  0.402  0.293
# 2           Denver Nuggets  0.488  0.329  0.207  0.524  0.598  0.537  0.549
# 3         Dallas Mavericks  0.646  0.695  0.732  0.634  0.707  0.732  0.817
# 4            Chicago Bulls  0.183  0.256  0.366  0.280  0.573  0.500  0.598
# 5      Cleveland Cavaliers  0.366  0.354  0.207  0.427  0.512  0.610  0.610
# 6        Charlotte Hornets  0.520  0.598  0.561  0.537  0.220  0.317  0.402
# 7            Brooklyn Nets  0.317  0.634  0.598  0.573  0.512  0.598  0.500
# 8          Detroit Pistion  0.390  0.610  0.610  0.659  0.659  0.780  0.646
# 9    Golden state Warriors  0.207  0.256  0.463  0.451  0.415  0.415  0.512
# 10         Houston Rockets  0.549  0.341  0.524  0.549  0.622  0.415  0.634
# ...

# %%
testtrans = test.T
testtrans
# Out:
#       count      mean       std    min      25%     50%      75%    max
# 2000   30.0  0.498600  0.154048  0.183  0.38100  0.5305  0.61900  0.707
# 2001   30.0  0.504467  0.137245  0.256  0.41125  0.5180  0.59800  0.744
# 2002   30.0  0.499600  0.141498  0.207  0.43300  0.5180  0.59475  0.732
# 2003   30.0  0.491833  0.143397  0.220  0.40200  0.5000  0.60075  0.744
# 2004   30.0  0.508200  0.145702  0.159  0.41500  0.5305  0.60700  0.756
# 2005   30.0  0.500433  0.136224  0.256  0.41500  0.5000  0.59175  0.780
# 2006   30.0  0.506867  0.136325  0.268  0.40200  0.5000  0.60700  0.817
# 2007   30.0  0.497133  0.166270  0.183  0.39300  0.5000  0.63100  0.805
# 2008   30.0  0.495200  0.171336  0.207  0.39300  0.4880  0.63700  0.805
# 2009   30.0  0.503700  0.163054  0.146  0.35400  0.5490  0.63700  0.744
# 2010   30.0  0.491900  0.163580  0.207  0.37200  0.4940  0.62800  0.756
# 2011   30.0  0.500267  0.155703  0.106  0.35575  0.5375  0.60600  0.758
# ...

# %%
testtrans["std"].mean()
# Out:
# 0.1523665345903891

# %%
fahrenheit, = plt.plot(df["Teams"], df["Avg Winning rate"],color="blue", linewidth=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Avg Winning rate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-52eaccc6dde8> in <module>()
# ...

# %%
df2000 = df.nlargest(5,"2000")
df2000 = df2000.reset_index(drop=True)
#df2000
new_df2000 = df2000["2000"]
new_df2000
# Out:
# 0    0.707
# 1    0.683
# 2    0.683
# 3    0.671
# 4    0.646
# Name: 2000, dtype: float64

# %%
df2001 = df.nlargest(5,"2001")
df2001 = df2001.reset_index(drop=True)
new_df2001 = df2001["2001"]

df2002 = df.nlargest(5,"2002")
df2002 = df2002.reset_index(drop=True)
new_df2002 = df2002["2002"]

df2003 = df.nlargest(5,"2003")
df2003 = df2003.reset_index(drop=True)
new_df2003 = df2003["2003"]

df2004 = df.nlargest(5,"2004")
df2004 = df2004.reset_index(drop=True)
new_df2004 = df2004["2004"]

df2005 = df.nlargest(5,"2005")
df2005 = df2005.reset_index(drop=True)
new_df2005 = df2005["2005"]

df2006 = df.nlargest(5,"2006")
df2006 = df2006.reset_index(drop=True)
new_df2006 = df2006["2006"]

df2007 = df.nlargest(5,"2007")
df2007 = df2007.reset_index(drop=True)
new_df2007 = df2007["2007"]

df2008 = df.nlargest(5,"2008")
df2008 = df2008.reset_index(drop=True)
new_df2008 = df2008["2008"]

df2009 = df.nlargest(5,"2009")
df2009 = df2009.reset_index(drop=True)
new_df2009 = df2009["2009"]

df2010 = df.nlargest(5,"2010")
df2010 = df2010.reset_index(drop=True)
new_df2010 = df2010["2010"]

df2011 = df.nlargest(5,"2011")
df2011 = df2011.reset_index(drop=True)
new_df2011 = df2011["2011"]

df2012 = df.nlargest(5,"2012")
df2012 = df2012.reset_index(drop=True)
new_df2012 = df2012["2012"]

df2013 = df.nlargest(5,"2013")
df2013 = df2013.reset_index(drop=True)
new_df2013 = df2013["2013"]


df2014 = df.nlargest(5,"2014")
df2014 = df2014.reset_index(drop=True)
new_df2014 = df2014["2014"]


df2015 = df.nlargest(5,"2015")
df2015 = df2015.reset_index(drop=True)
new_df2015 = df2015["2015"]


df2016 = df.nlargest(5,"2016")
df2016 = df2016.reset_index(drop=True)
new_df2016 = df2016["2016"]


df2017 = df.nlargest(5,"2017")
df2017 = df2017.reset_index(drop=True)
new_df2017 = df2017["2017"]

# %%
df_col_merged1 =pd.concat([new_df2000,new_df2001,new_df2002,new_df2003,new_df2004,new_df2005,new_df2006,new_df2007,
                          new_df2008,new_df2009,new_df2010,new_df2011,new_df2012,new_df2013,new_df2014,new_df2015,
                         new_df2016,new_df2017], axis=1)
df_col_merged1
# Out:
#     2000   2001   2002   2003   2004   2005   2006   2007   2008   2009  \
# 0  0.707  0.744  0.732  0.744  0.756  0.780  0.817  0.805  0.805  0.744
# 1  0.683  0.707  0.732  0.707  0.720  0.768  0.744  0.720  0.793  0.720
# 2  0.683  0.707  0.720  0.695  0.720  0.732  0.707  0.695  0.756  0.695
# 3  0.671  0.695  0.622  0.683  0.707  0.659  0.683  0.683  0.720  0.671
# 4  0.646  0.634  0.610  0.671  0.659  0.634  0.646  0.671  0.659  0.659
#
#     2010   2011   2012   2013   2014   2015   2016   2017
# 0  0.756  0.758  0.805  0.756  0.817  0.890  0.817  0.793
# 1  0.744  0.758  0.732  0.720  0.732  0.817  0.744  0.720
# 2  0.707  0.712  0.707  0.695  0.683  0.695  0.671  0.707
# 3  0.695  0.697  0.695  0.683  0.683  0.683  0.646  0.671
# 4  0.695  0.636  0.683  0.659  0.671  0.671  0.622  0.634

# %%
dfs2000 = df.nsmallest(5,"2000")
dfs2000 = dfs2000.reset_index(drop=True)
new_dfs2000 = dfs2000["2000"]

dfs2001 = df.nsmallest(5,"2001")
dfs2001 = dfs2001.reset_index(drop=True)
new_dfs2001 = dfs2001["2001"]

dfs2002 = df.nsmallest(5,"2002")
dfs2002 = dfs2002.reset_index(drop=True)
new_dfs2002 = dfs2002["2002"]

dfs2003 = df.nsmallest(5,"2003")
dfs2003 = dfs2003.reset_index(drop=True)
new_dfs2003 = dfs2003["2003"]

dfs2004 = df.nsmallest(5,"2004")
dfs2004 = dfs2004.reset_index(drop=True)
new_dfs2004 = dfs2004["2004"]

dfs2005 = df.nsmallest(5,"2005")
dfs2005 = dfs2005.reset_index(drop=True)
new_dfs2005 = dfs2005["2005"]

dfs2006 = df.nsmallest(5,"2006")
dfs2006 = dfs2006.reset_index(drop=True)
new_dfs2006 = dfs2006["2006"]

dfs2007 = df.nsmallest(5,"2007")
dfs2007 = dfs2007.reset_index(drop=True)
new_dfs2007 = dfs2007["2007"]

dfs2008 = df.nsmallest(5,"2008")
dfs2008 = dfs2008.reset_index(drop=True)
new_dfs2008 = dfs2008["2008"]

dfs2009 = df.nsmallest(5,"2009")
dfs2009 = dfs2009.reset_index(drop=True)
new_dfs2009 = dfs2009["2009"]

dfs2010 = df.nsmallest(5,"2010")
dfs2010 = dfs2010.reset_index(drop=True)
new_dfs2010 = dfs2010["2010"]

dfs2011 = df.nsmallest(5,"2011")
dfs2011 = dfs2011.reset_index(drop=True)
new_dfs2011 = dfs2011["2011"]

dfs2012 = df.nsmallest(5,"2012")
dfs2012 = dfs2012.reset_index(drop=True)
new_dfs2012 = dfs2012["2012"]

dfs2013 = df.nsmallest(5,"2013")
dfs2013 = dfs2013.reset_index(drop=True)
new_dfs2013 = dfs2013["2013"]


dfs2014 = df.nsmallest(5,"2014")
dfs2014 = dfs2014.reset_index(drop=True)
new_dfs2014 = dfs2014["2014"]


dfs2015 = df.nsmallest(5,"2015")
dfs2015 = dfs2015.reset_index(drop=True)
new_dfs2015 = dfs2015["2015"]


dfs2016 = df.nsmallest(5,"2016")
dfs2016 = dfs2016.reset_index(drop=True)
new_dfs2016 = dfs2016["2016"]


dfs2017 = df.nsmallest(5,"2017")
dfs2017 = dfs2017.reset_index(drop=True)
new_dfs2017 = dfs2017["2017"]

# %%
df_col_merged2 =pd.concat([new_dfs2000,new_dfs2001,new_dfs2002,new_dfs2003,new_dfs2004,new_dfs2005,new_dfs2006,new_dfs2007,
                          new_dfs2008,new_dfs2009,new_dfs2010,new_dfs2011,new_dfs2012,new_dfs2013,new_dfs2014,new_dfs2015,
                         new_dfs2016,new_dfs2017], axis=1)
df_col_merged2
# Out:
#     2000   2001   2002   2003   2004   2005   2006   2007   2008   2009  \
# 0  0.183  0.256  0.207  0.220  0.159  0.256  0.268  0.183  0.207  0.146
# 1  0.207  0.256  0.207  0.256  0.220  0.280  0.293  0.244  0.232  0.183
# 2  0.232  0.280  0.293  0.280  0.317  0.317  0.341  0.268  0.232  0.305
# 3  0.280  0.329  0.305  0.305  0.329  0.317  0.366  0.268  0.280  0.317
# 4  0.305  0.341  0.329  0.341  0.366  0.329  0.378  0.280  0.293  0.317
#
#     2010   2011   2012   2013   2014   2015   2016   2017
# 0  0.207  0.106  0.244  0.183  0.195  0.122  0.244  0.256
# 1  0.232  0.303  0.256  0.232  0.207  0.207  0.293  0.268
# 2  0.268  0.318  0.293  0.280  0.220  0.256  0.317  0.293
# 3  0.280  0.329  0.305  0.305  0.256  0.280  0.341  0.293
# 4  0.293  0.333  0.341  0.305  0.305  0.354  0.354  0.305

# %%
df_col_merged2_t = df_col_merged2.T
df_col_merged2_t
# Out:
#           0      1      2      3      4
# 2000  0.183  0.207  0.232  0.280  0.305
# 2001  0.256  0.256  0.280  0.329  0.341
# 2002  0.207  0.207  0.293  0.305  0.329
# 2003  0.220  0.256  0.280  0.305  0.341
# 2004  0.159  0.220  0.317  0.329  0.366
# 2005  0.256  0.280  0.317  0.317  0.329
# 2006  0.268  0.293  0.341  0.366  0.378
# 2007  0.183  0.244  0.268  0.268  0.280
# 2008  0.207  0.232  0.232  0.280  0.293
# 2009  0.146  0.183  0.305  0.317  0.317
# 2010  0.207  0.232  0.268  0.280  0.293
# 2011  0.106  0.303  0.318  0.329  0.333
# 2012  0.244  0.256  0.293  0.305  0.341
# 2013  0.183  0.232  0.280  0.305  0.305
# 2014  0.195  0.207  0.220  0.256  0.305
# 2015  0.122  0.207  0.256  0.280  0.354
# 2016  0.244  0.293  0.317  0.341  0.354
# 2017  0.256  0.268  0.293  0.293  0.305

# %%
plt.plot(df_col_merged2_t, marker = "o", alpha = 325)
plt.xticks(rotation = 45)
plt.xlabel("Year")
plt.ylabel("Winning %")
plt.title("NBA Bottom 5 Winning % By Year")
plt.savefig("NBA Bottom 5 Winning % By Year")
plt.show()

# %%
df_col_merged1_t = df_col_merged1.T
df_col_merged1_t
# Out:
#           0      1      2      3      4
# 2000  0.707  0.683  0.683  0.671  0.646
# 2001  0.744  0.707  0.707  0.695  0.634
# 2002  0.732  0.732  0.720  0.622  0.610
# 2003  0.744  0.707  0.695  0.683  0.671
# 2004  0.756  0.720  0.720  0.707  0.659
# 2005  0.780  0.768  0.732  0.659  0.634
# 2006  0.817  0.744  0.707  0.683  0.646
# 2007  0.805  0.720  0.695  0.683  0.671
# 2008  0.805  0.793  0.756  0.720  0.659
# 2009  0.744  0.720  0.695  0.671  0.659
# 2010  0.756  0.744  0.707  0.695  0.695
# 2011  0.758  0.758  0.712  0.697  0.636
# 2012  0.805  0.732  0.707  0.695  0.683
# 2013  0.756  0.720  0.695  0.683  0.659
# 2014  0.817  0.732  0.683  0.683  0.671
# 2015  0.890  0.817  0.695  0.683  0.671
# 2016  0.817  0.744  0.671  0.646  0.622
# 2017  0.793  0.720  0.707  0.671  0.634

# %%
plt.plot(df_col_merged1_t, marker = "o", alpha = 325)
plt.xticks(rotation = 45)
plt.xlabel("Year")
plt.ylabel("Winning %")
plt.title("NBA Top 5 Winning % By Year")
plt.savefig("NBA Top 5 Winning % By Year")
plt.show()

# %%
MeanTop5 = df_col_merged1_t.mean()

MeanBottom5 = df_col_merged2_t.mean()
MeanBottom5.mean()
MeanTop5.mean()
# Out:
# 0.7109000000000001
