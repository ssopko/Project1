# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import csv

# Import API key
from api_keys import api_key

# %%
import requests

nba = requests.get('https://api.mysportsfeeds.com/v2.0/pull/nba/injuries.json', auth=(api_key, 'MYSPORTSFEEDS'))
pprint(nba.text)
# Out:
# ('{"lastUpdatedOn":"2019-01-08T12:25:28.768Z","players":[{"id":10138,"firstName":"Alex","lastName":"Abrines","primaryPosition":"SG","jerseyNumber":8,"currentTeam":{"id":96,"abbreviation":"OKL"},"currentRosterStatus":"ROSTER","currentInjury":{"description":"personal","playingProbability":"OUT"},"height":"6\'6\\"","weight":190,"birthDate":"1993-08-01","age":25,"birthCity":"Palma '
#  'de '
#  'Mallorca","birthCountry":"Spain","rookie":false,"highSchool":null,"college":null,"handedness":{"shoots":"R"},"officialImageSrc":null,"socialMediaAccounts":[]},{"id":15218,"firstName":"Grayson","lastName":"Allen","primaryPosition":"SG","jerseyNumber":24,"currentTeam":{"id":98,"abbreviation":"UTA"},"currentRosterStatus":"ROSTER","currentInjury":{"description":"sprained '
#  'right '
#  'ankle","playingProbability":"OUT"},"height":"6\'5\\"","weight":198,"birthDate":"1995-10-07","age":23,"birthCity":"Jacksonville, '
# ...

# %%
nba_data = nba.json()
nba_injuries = nba_data["players"]
pprint(nba_injuries)
# Out:
# [{'age': 25,
#   'birthCity': 'Palma de Mallorca',
#   'birthCountry': 'Spain',
#   'birthDate': '1993-08-01',
#   'college': None,
#   'currentInjury': {'description': 'personal', 'playingProbability': 'OUT'},
#   'currentRosterStatus': 'ROSTER',
#   'currentTeam': {'abbreviation': 'OKL', 'id': 96},
#   'firstName': 'Alex',
#   'handedness': {'shoots': 'R'},
#   'height': '6\'6"',
#   'highSchool': None,
#   'id': 10138,
#   'jerseyNumber': 8,
#   'lastName': 'Abrines',
#   'officialImageSrc': None,
#   'primaryPosition': 'SG',
#   'rookie': False,
#   'socialMediaAccounts': [],
#   'weight': 190},
#  {'age': 23,
#   'birthCity': 'Jacksonville, FL',
#   'birthCountry': 'USA',
#   'birthDate': '1995-10-07',
#   'college': None,
#   'currentInjury': {'description': 'sprained right ankle',
#                     'playingProbability': 'OUT'},
#   'currentRosterStatus': 'ROSTER',
#   'currentTeam': {'abbreviation': 'UTA', 'id': 98},
#   'firstName': 'Grayson',
# ...

# %%
nba_injuries_df = pd.DataFrame(nba_injuries)
nba_injuries_df
# Out:
#     age             birthCity birthCountry   birthDate  \
# 0    25     Palma de Mallorca        Spain  1993-08-01
# 1    23      Jacksonville, FL          USA  1995-10-07
# 2    20         San Diego, CA          USA  1998-10-16
# 3    34          New York, NY          USA  1984-05-27
# 4    19             Tempe, AZ          USA  1999-03-12
# 5    34              Mayaguez  Puerto Rico  1984-06-26
# 6    28         Baltimore, MD          USA  1991-01-06
# 7    32              Gisborne  New Zealand  1986-12-09
# 8    29           Kelford, NC          USA  1989-07-01
# 9    24      Walnut Creek, CA          USA  1994-07-01
# 10   22      Grand Rapids, MI          USA  1996-10-30
# 11   22           Mississauga       Canada  1996-01-22
# 12   22          Marietta, GA          USA  1996-10-23
# 13   29           Houston, TX          USA  1989-09-11
# 14   32        Birmingham, AL          USA  1986-07-27
# 15   23          Oak Park, IL          USA  1995-09-14
# ...

# %%
nba_injuries_df.groupby("primaryPosition").count()
# Out:
#                  age  birthCity  birthCountry  birthDate  college  \
# primaryPosition
# C                 18         18            18         18       11
# G                  1          1             1          1        0
# PF                13         13            13         13       11
# PG                18         18            18         18       12
# SF                19         19            19         19       14
# SG                23         23            23         23       16
#
#                  currentInjury  currentRosterStatus  currentTeam  firstName  \
# primaryPosition
# C                           18                   18           18         18
# G                            1                    1            1          1
# PF                          13                   13           13         13
# PG                          18                   18           18         18
# SF                          19                   19           19         19
# ...

# %%
nba_injuries_df.groupby("rookie").count()
# Out:
#         age  birthCity  birthCountry  birthDate  college  currentInjury  \
# rookie
# False    81         81            81         81       64             81
# True     11         11            11         11        0             11
#
#         currentRosterStatus  currentTeam  firstName  handedness  height  \
# rookie
# False                    81           81         81          81      81
# True                     11           11         11          11      11
#
#         highSchool  id  jerseyNumber  lastName  officialImageSrc  \
# rookie
# False           67  81            81        81                 0
# True             0  11            10        11                 0
#
#         primaryPosition  socialMediaAccounts  weight
# rookie
# False                81                   81      81
# True                 11                   11      11
