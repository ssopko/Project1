# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import csv

# Import API key
from api_keys import api_key

# %%
import requests

mlb = requests.get('https://api.mysportsfeeds.com/v2.0/pull/mlb/injuries.json', auth=(api_key, 'MYSPORTSFEEDS'))
pprint(mlb.text)
# Out:
# ('{"lastUpdatedOn":"2019-01-08T23:19:21.434Z","players":[{"id":10495,"firstName":"Jose","lastName":"Altuve","primaryPosition":"2B","jerseyNumber":27,"currentTeam":{"id":122,"abbreviation":"HOU"},"currentRosterStatus":"ROSTER","currentInjury":{"description":"knee","playingProbability":"PROBABLE"},"height":"5\'6\\"","weight":165,"birthDate":"1990-05-06","age":28,"birthCity":"Maracay","birthCountry":"Venezuela","rookie":false,"highSchool":null,"college":null,"handedness":{"bats":"R","throws":"R"},"officialImageSrc":null,"socialMediaAccounts":[{"mediaType":"TWITTER","value":"JoseAltuve27"}]},{"id":10680,"firstName":"Erik","lastName":"Goeddel","primaryPosition":"P","jerseyNumber":62,"currentTeam":{"id":137,"abbreviation":"LAD"},"currentRosterStatus":"ROSTER","currentInjury":{"description":"right '
#  'elbow '
#  'inflammation","playingProbability":"OUT"},"height":"6\'3\\"","weight":191,"birthDate":"1988-12-18","age":30,"birthCity":"San '
#  'Mateo, '
# ...

# %%
mlb_data = mlb.json()
mlb_injuries = mlb_data["players"]
pprint(mlb_injuries)
# Out:
# [{'age': 28,
#   'birthCity': 'Maracay',
#   'birthCountry': 'Venezuela',
#   'birthDate': '1990-05-06',
#   'college': None,
#   'currentInjury': {'description': 'knee', 'playingProbability': 'PROBABLE'},
#   'currentRosterStatus': 'ROSTER',
#   'currentTeam': {'abbreviation': 'HOU', 'id': 122},
#   'firstName': 'Jose',
#   'handedness': {'bats': 'R', 'throws': 'R'},
#   'height': '5\'6"',
#   'highSchool': None,
#   'id': 10495,
#   'jerseyNumber': 27,
#   'lastName': 'Altuve',
#   'officialImageSrc': None,
#   'primaryPosition': '2B',
#   'rookie': False,
#   'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'JoseAltuve27'}],
#   'weight': 165},
#  {'age': 30,
#   'birthCity': 'San Mateo, CA',
#   'birthCountry': 'USA',
#   'birthDate': '1988-12-18',
#   'college': 'UCLA',
#   'currentInjury': {'description': 'right elbow inflammation',
#                     'playingProbability': 'OUT'},
#   'currentRosterStatus': 'ROSTER',
# ...

# %%
mlb_injuries_df = pd.DataFrame(mlb_injuries)
mlb_injuries_df
# Out:
#     age             birthCity        birthCountry   birthDate  \
# 0    28               Maracay           Venezuela  1990-05-06
# 1    30         San Mateo, CA                 USA  1988-12-18
# 2    29          Puerto Ordaz           Venezuela  1989-03-14
# 3    30                Havana                Cuba  1988-11-08
# 4    26              Santiago  Dominican Republic  1992-09-06
# 5    31         Lynchburg, VA                 USA  1987-03-08
# 6    32             Bronx, NY                 USA  1986-06-29
# 7    27      Jacksonville, FL                 USA  1991-05-13
# 8    33             Amory, MS                 USA  1985-09-06
# 9    29     Klamath Falls, OR                 USA  1989-06-04
# 10   35          Woodland, CA                 USA  1983-08-17
# 11   29          Lakeland, FL                 USA  1989-03-30
# 12   22  San Pedro de Macoris  Dominican Republic  1996-04-12
# 13   24         Charlotte, NC                 USA  1994-04-27
# ...

# %%
mlb_injuries_df.groupby("primaryPosition").count()
# Out:
#                  age  birthCity  birthCountry  birthDate  college  \
# primaryPosition
# 1B                 2          2             2          2        1
# 2B                 2          2             2          2        1
# C                  2          2             2          2        2
# P                 12         12            12         12       11
# SS                 2          2             2          2        0
#
#                  currentInjury  currentRosterStatus  currentTeam  firstName  \
# primaryPosition
# 1B                           2                    2            2          2
# 2B                           2                    2            2          2
# C                            2                    2            2          2
# P                           12                   12           12         12
# SS                           2                    2            2          2
#
# ...

# %%
mlb_injuries_df.groupby("rookie").count()
# Out:
#         age  birthCity  birthCountry  birthDate  college  currentInjury  \
# rookie
# False    71         71            71         71       55             71
# True      9          9             9          9        0              9
#
#         currentRosterStatus  currentTeam  firstName  handedness  height  \
# rookie
# False                    71           71         71          71      71
# True                      9            9          9           9       9
#
#         highSchool  id  jerseyNumber  lastName  officialImageSrc  \
# rookie
# False           58  71            71        71                 0
# True             0   9             8         9                 0
#
#         primaryPosition  socialMediaAccounts  weight
# rookie
# False                71                   71      71
# True                  9                    9       9
