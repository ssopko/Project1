# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import csv

# Import API key
from api_keys import api_key

# %%
import requests

nhl = requests.get('https://api.mysportsfeeds.com/v2.0/pull/nhl/injuries.json', auth=(api_key, 'MYSPORTSFEEDS'))
pprint(nhl.text)
# Out:
# ('{"lastUpdatedOn":"2019-01-08T12:20:44.840Z","players":[{"id":5109,"firstName":"Frederik","lastName":"Andersen","primaryPosition":"G","jerseyNumber":31,"currentTeam":{"id":12,"abbreviation":"TOR"},"currentRosterStatus":"ROSTER","currentInjury":{"description":"groin","playingProbability":"QUESTIONABLE"},"height":"6\'4\\"","weight":230,"birthDate":"1989-09-30","age":29,"birthCity":"Herning","birthCountry":"Denmark","rookie":false,"highSchool":null,"college":null,"handedness":{"catches":null},"officialImageSrc":null,"socialMediaAccounts":[{"mediaType":"TWITTER","value":"f_andersen30"}]},{"id":757,"firstName":"Craig","lastName":"Anderson","primaryPosition":"G","jerseyNumber":41,"currentTeam":{"id":13,"abbreviation":"OTT"},"currentRosterStatus":"ROSTER","currentInjury":{"description":"concussion","playingProbability":"OUT"},"height":"6\'2\\"","weight":187,"birthDate":"1981-05-21","age":37,"birthCity":"Park '
#  'Ridge, '
# ...

# %%
nhl_data = nhl.json()
nhl_injuries = nhl_data["players"]
pprint(nhl_injuries)
# Out:
# [{'age': 29,
#   'birthCity': 'Herning',
#   'birthCountry': 'Denmark',
#   'birthDate': '1989-09-30',
#   'college': None,
#   'currentInjury': {'description': 'groin',
#                     'playingProbability': 'QUESTIONABLE'},
#   'currentRosterStatus': 'ROSTER',
#   'currentTeam': {'abbreviation': 'TOR', 'id': 12},
#   'firstName': 'Frederik',
#   'handedness': {'catches': None},
#   'height': '6\'4"',
#   'highSchool': None,
#   'id': 5109,
#   'jerseyNumber': 31,
#   'lastName': 'Andersen',
#   'officialImageSrc': None,
#   'primaryPosition': 'G',
#   'rookie': False,
#   'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'f_andersen30'}],
#   'weight': 230},
#  {'age': 37,
#   'birthCity': 'Park Ridge, IL',
#   'birthCountry': 'USA',
#   'birthDate': '1981-05-21',
#   'college': None,
#   'currentInjury': {'description': 'concussion', 'playingProbability': 'OUT'},
#   'currentRosterStatus': 'ROSTER',
#   'currentTeam': {'abbreviation': 'OTT', 'id': 13},
# ...

# %%
nhl_injuries_df = pd.DataFrame(nhl_injuries)
nhl_injuries_df
# Out:
#      age             birthCity   birthCountry   birthDate college  \
# 0     29               Herning        Denmark  1989-09-30    None
# 1     37        Park Ridge, IL            USA  1981-05-21    None
# 2     20         Roseville, MN            USA  1998-06-17    None
# 3     28          Montreal, QC         Canada  1990-03-22    None
# 4     24          Edmonton, AB         Canada  1994-05-25    None
# 5     22        St. John's, NL         Canada  1996-03-29    None
# 6     26       Minneapolis, MN            USA  1992-07-17    None
# 7     22                  None           None  1996-12-09    None
# 8     32            Regina, SK         Canada  1986-03-17    None
# 9     31       Minneapolis, MN            USA  1987-02-10    None
# 10    25          Ham Lake, MN            USA  1993-06-19    None
# 11    33            Roseau, MN            USA  1985-03-27    None
# 12    24           LaSalle, QC         Canada  1994-12-20    None
# ...

# %%
nhl_injuries_df.groupby("primaryPosition").count()
# Out:
#                  age  birthCity  birthCountry  birthDate  college  \
# primaryPosition
# C                 31         31            31         31        0
# D                 36         36            36         36        0
# G                 12         11            11         12        0
# LW                13         13            13         13        0
# RW                 9          9             9          9        0
#
#                  currentInjury  currentRosterStatus  currentTeam  firstName  \
# primaryPosition
# C                           31                   31           31         31
# D                           36                   36           36         36
# G                           12                   12           12         12
# LW                          13                   13           13         13
# RW                           9                    9            9          9
#
# ...

# %%
nhl_injuries_df.groupby("rookie").count()
# Out:
#         age  birthCity  birthCountry  birthDate  college  currentInjury  \
# rookie
# False    91         91            91         91        0             91
# True     10          9             9         10        0             10
#
#         currentRosterStatus  currentTeam  firstName  handedness  height  \
# rookie
# False                    91           91         91          91      91
# True                     10           10         10          10       9
#
#         highSchool  id  jerseyNumber  lastName  officialImageSrc  \
# rookie
# False            0  91            91        91                 0
# True             0  10             9        10                 0
#
#         primaryPosition  socialMediaAccounts  weight
# rookie
# False                91                   91      91
# True                 10                   10       9
