# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import csv

# Import API key
from api_keys import api_key

# %%
import requests

nfl = requests.get('https://api.mysportsfeeds.com/v2.0/pull/nfl/injuries.json', auth=(api_key, 'MYSPORTSFEEDS'))
pprint(nfl.text)
# Out:
# ('{"lastUpdatedOn":"2019-01-07T13:05:48.495Z","players":[{"id":7369,"firstName":"Jay","lastName":"Ajayi","primaryPosition":"RB","jerseyNumber":23,"currentTeam":{"id":54,"abbreviation":"PHI"},"currentRosterStatus":"INJURY_LIST","currentInjury":{"description":"torn '
#  'acl in his left '
#  'knee","playingProbability":"QUESTIONABLE"},"height":"6\'0\\"","weight":228,"birthDate":"1993-06-15","age":25,"birthCity":"London","birthCountry":"England","rookie":false,"highSchool":null,"college":null,"handedness":null,"officialImageSrc":null,"socialMediaAccounts":[]},{"id":7331,"firstName":"D.J.","lastName":"Alexander","primaryPosition":"LB","jerseyNumber":57,"currentTeam":{"id":54,"abbreviation":"PHI"},"currentRosterStatus":"ROSTER","currentInjury":{"description":"hamstring","playingProbability":"QUESTIONABLE"},"height":"6\'2\\"","weight":233,"birthDate":"1991-09-29","age":27,"birthCity":"Long '
#  'Beach, '
# ...

# %%
nfl_data = nfl.json()
nfl_injuries = nfl_data["players"]
pprint(nfl_injuries)
# Out:
# [{'age': 25,
#   'birthCity': 'London',
#   'birthCountry': 'England',
#   'birthDate': '1993-06-15',
#   'college': None,
#   'currentInjury': {'description': 'torn acl in his left knee',
#                     'playingProbability': 'QUESTIONABLE'},
#   'currentRosterStatus': 'INJURY_LIST',
#   'currentTeam': {'abbreviation': 'PHI', 'id': 54},
#   'firstName': 'Jay',
#   'handedness': None,
#   'height': '6\'0"',
#   'highSchool': None,
#   'id': 7369,
#   'jerseyNumber': 23,
#   'lastName': 'Ajayi',
#   'officialImageSrc': None,
#   'primaryPosition': 'RB',
#   'rookie': False,
#   'socialMediaAccounts': [],
#   'weight': 228},
#  {'age': 27,
#   'birthCity': 'Long Beach, CA',
#   'birthCountry': 'USA',
#   'birthDate': '1991-09-29',
#   'college': None,
#   'currentInjury': {'description': 'hamstring',
#                     'playingProbability': 'QUESTIONABLE'},
#   'currentRosterStatus': 'ROSTER',
#   'currentTeam': {'abbreviation': 'PHI', 'id': 54},
#   'firstName': 'D.J.',
# ...

# %%
nfl_injuries_df = pd.DataFrame(nfl_injuries)
nfl_injuries_df
# Out:
#       age               birthCity birthCountry   birthDate      college  \
# 0    25.0                  London      England  1993-06-15         None
# 1    27.0          Long Beach, CA          USA  1991-09-29         None
# 2    29.0             Chicago, IL          USA  1990-01-07         None
# 3    23.0                    None          USA  1995-09-04         None
# 4     NaN                    None         None        None         None
# 5    22.0           Nashville, TN          USA  1996-06-25         None
# 6    29.0             Houston, TX          USA  1989-04-25         None
# 7    22.0                    None         None  1996-08-23         None
# 8    23.0             Raleigh, NC          USA  1995-10-06         None
# 9     NaN                    None         None        None         None
# 10   26.0               Laval, QC       Canada  1992-08-14         None
# 11   26.0            New York, NY          USA  1992-05-28         None
# ...

# %%
nfl_injuries_df.groupby("primaryPosition").count()
# Out:
#                  age  birthCity  birthCountry  birthDate  college  \
# primaryPosition
# C                  1          1             1          1        0
# CB                 7          7             7          7        0
# DB                 9          6             6          9        0
# DE                 6          3             3          6        0
# DT                 5          4             4          5        0
# FS                 4          3             3          4        0
# G                  7          6             6          7        0
# ILB                4          2             2          4        0
# LB                 5          4             4          5        0
# NT                 1          1             1          1        0
# OT                 6          6             6          6        0
# QB                 2          2             2          2        0
# RB                 7          6             6          7        0
# ...

# %%
nfl_injuries_df.groupby("rookie").count()
# Out:
#         age  birthCity  birthCountry  birthDate  college  currentInjury  \
# rookie
# False    98         81            82         98        4            111
#
#         currentRosterStatus  currentTeam  firstName  handedness  height  \
# rookie
# False                   111          111        111           2     110
#
#         highSchool   id  jerseyNumber  lastName  officialImageSrc  \
# rookie
# False            0  111           106       111                 0
#
#         primaryPosition  socialMediaAccounts  weight
# rookie
# False               111                  111     110
